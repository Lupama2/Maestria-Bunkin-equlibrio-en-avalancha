# %% [markdown]
# <a href="https://colab.research.google.com/github/Lupama2/Maestria-Bunkin/blob/main/Dependencia_laser_Rmax/Simulacion_particulas_equlibrio/simulacion_de_particulas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Simulación de partículas
# versión python cpu

# %% [markdown]
# ## Importo dependencias

# %%
#Importo librerías
import numpy as np
import os

# %% [markdown]
# ## Defino ctes

# %%
#Constantes matemáticas
pi = np.pi

#Ctes físicas
m = 9.11e-31*1e3 #[g]
e = 1.602e-19*(1/3.336641e-10) #[Fr]
c = 299792458*1e2 #[cm/s]
K = 1.380649e-23*(1/1e-7) #constante de Boltzmann [ergio/K], obtenida de NIST

# %% [markdown]
# ## C.I. (Condiciones Iniciales)
#
# A partir de ahora todas las variables definidas son adimensionales. Las variables que posean dimensiones se declararán con el sufico _dim

# %%
#Radio del círculo y velocidad inicial de la partícula
R0_dim = 1e-6 #[cm]
T0_dim = 1000 #[K]

# %%
#Calculo las ctes adimensionales
v0_dim = np.sqrt(3*K*T0_dim/m)
alpha = e**2/m/R0_dim/(v0_dim**2)
print(f"Constante adimensional, alpha = {alpha}")

#Radio del círculo y velocidad inicial de la partícula adimensionales
R0 = 1
v0 = 1

print("Radio y velocidad iniciales adimensionales: ", R0, ",\t", v0)
# Out:
# Constante adimensional, alpha = 0.5565465847665151
# Radio y velocidad iniciales adimensionales:  1 ,	 1

# %% [markdown]
# ## Sistema de ecuaciones diferenciales

# %%
def f(y, N):
    '''
    Evaluación del miembro de la derecha del sistema de ecuaciones diferenciales del tipo dy_vec/dt = f(y_vec, t)
    Parameters
    ----------
    y_vec (ndarray de dimensión 4N): vector de variables formado por [rx_vec, ry_vec, vx_vec, vy_vec] (en ese orden). Estos son:
        rx_vec (ndarray de dimensión N): vector de posiciones en x de las partículas
        ry_vec (ndarray de dimensión N): vector de posiciones en y de las partículas
        vx_vec (ndarray de dimensión N): vector de velocidades en x de las partículas
        vy_vec (ndarray de dimensión N): vector de velocidades en y de las partículas
    N (int): nro de partículas
    
    '''
    rx_vec = y[:N]
    ry_vec = y[N:2*N]
    vx_vec = y[2*N:3*N]
    vy_vec = y[3*N:4*N]


    #Calculo drdt
    drx_vec = vx_vec
    dry_vec = vy_vec

    #Calculo dvdt
    Ax_matriz = np.tile(rx_vec, (N,1))
    Ay_matriz = np.tile(ry_vec, (N,1))

    Bx_matriz = Ax_matriz.T - Ax_matriz
    By_matriz = Ay_matriz.T - Ay_matriz

    modulo = np.sqrt(Bx_matriz**2 + By_matriz**2)
    modulo = np.where(modulo == 0, 1, modulo) #Para evitar división por cero

    Cx_matriz = Bx_matriz/modulo**3
    Cy_matriz = By_matriz/modulo**3

    dvx_vec = alpha*np.sum(Cx_matriz, axis=1)
    dvy_vec = alpha*np.sum(Cy_matriz, axis=1)
   
    dydt = np.concatenate((drx_vec, dry_vec, dvx_vec, dvy_vec))

    return dydt

# %%
from scipy.stats import maxwell

def f_maxwell(N):
    '''
    Devuelve un vector de N velocidades iniciales adimensionales de acuerdo a una distribución de Maxwell-Boltzmann

    Parameters
    ----------
    N (int): nro de partículas
    '''

    factor_Chi_to_v = 1/np.sqrt(m/(K*T0_dim))
    return maxwell.rvs(N)*factor_Chi_to_v/v0_dim


def condiciones_iniciales(N):
    '''
    Devuelve un vector de condiciones iniciales adimensionales

    Parameters
    ----------
    N (int): nro de partículas

    Nota:
    (1) Las posiciones iniciales se distribuyen aleatoriamente en el círculo de radio R0
    (2) Las velocidades iniciales se distribuyen de acuerdo a una distribución de Maxwell-Boltzmann, pero su dirección es aleatoria con distribución uniforme
    '''
    y0 = np.empty(4*N)

    #Posiciones aleatorias
    r0_vec = R0*np.random.rand(N)
    tita0_vec = 2*pi*np.random.rand(N)
    y0[:N] = r0_vec*np.cos(tita0_vec) # = rx0_vec[i]
    y0[N:2*N] = r0_vec*np.sin(tita0_vec) # = ry0_vec[i] 

    #Velocidades de acuerdo a una distribución de Maxwell-Boltzmann 
    v0_vec = f_maxwell(N)
    tita0_vec = 2*pi*np.random.rand(N)
    y0[2*N:3*N] = v0_vec*np.cos(tita0_vec) # = vx0_vec[i]
    y0[3*N:4*N] = v0_vec*np.sin(tita0_vec) # = vy0_vec[i]

    return y0

# %%
def distancia_al_origen(r_vec, N):
    '''
    Calcula la distancia al origen de las partículas.

    Parameters
    ----------
    r_vec (ndarray de dimensión 2N): vector de posiciones de las partículas tal que r_vec = [rx_vec, ry_vec]
    N (int): nro de partículas
    '''

    #Opero de forma similar a como lo hice dentro de f
    rx = r_vec[:N]
    ry = r_vec[N:]

    d_vec = np.sqrt(rx**2 + ry**2)

    return d_vec

def correccion_Temperatura(vx_vec, vy_vec):
    '''
    Corrección de las velocidades para que la temperatura sea la deseada
    
    La temperatura de equilibrio debe ser adimensional
    '''
    #Cuentas previas
    N = len(vx_vec)
    #Calculo el factor de corrección
    lambda_ = np.sqrt((N-1)*2*K*T0_dim/(m*np.sum(vx_vec**2 + vy_vec**2)*v0_dim**2))

    #Corrijo
    vx_vec_new, vy_vec_new = lambda_*vx_vec, lambda_*vy_vec

    return vx_vec_new, vy_vec_new

# %% [markdown]
# ## Funciones útiles para la evolución

# %%
def rebote_duro(rx, ry, vx, vy):
    '''
    Calcula las posiciones y velocidades de una partícula luego del rebote con la pared. Se considera pared dura, es decir, en el choque no solo se invierte la velocidad, sino tmb se refleja su posición.

    Parameters
    ----------
    rx (float): posición x de la partícula
    ry (float): posición y de la partícula
    vx (float): velocidad x de la partícula
    vy (float): velocidad y de la partícula

    Returns
    -------
    rx_new (float): nueva posición x de la partícula
    ry_new (float): nueva posición y de la partícula
    vx_new (float): nueva velocidad x de la partícula
    vy_new (float): nueva velocidad y de la partícula

    Nota:
    Esta función no se emplea durante la evolución. Tiene el problema de que al mover discontinuamente una partícula, la energía potencial del sistema varía de forma discontínua, no conservandose la energía en algunos casos.
    '''

    #Calculo la nueva posición
    factor = -1 + 2*R0/np.sqrt(rx**2 + ry**2)

    rx_new = rx*factor
    ry_new = ry*factor

    #Calculo la nueva velocidad
    
    #Calculo el ángulo del vector [rx,ry]
    tita = np.arctan2(ry, rx)
    vx_new = -vx*np.cos(2*tita) - vy*np.sin(2*tita)
    vy_new = -vx*np.sin(2*tita) + vy*np.cos(2*tita)

    return rx_new, ry_new, vx_new, vy_new

def rebote_blando(rx, ry, vx, vy):
    '''
    Calcula las posiciones y velocidades de una partícula luego del rebote con la pared. Se considera pared blanda, es decir, en el choque solo se invierte la velocidad.

    
    Parameters
    ----------
    rx (float): posición x de la partícula
    ry (float): posición y de la partícula
    vx (float): velocidad x de la partícula
    vy (float): velocidad y de la partícula

    Returns
    -------
    rx_new (float): nueva posición x de la partícula
    ry_new (float): nueva posición y de la partícula
    vx_new (float): nueva velocidad x de la partícula
    vy_new (float): nueva velocidad y de la partícula
    '''

    #Calculo la nueva posición
    rx_new = rx
    ry_new = ry

    #Calculo la nueva velocidad
    
    #Calculo el ángulo del vector [rx,ry]
    tita = np.arctan2(ry, rx)
    vx_new = -vx*np.cos(2*tita) - vy*np.sin(2*tita)
    vy_new = -vx*np.sin(2*tita) + vy*np.cos(2*tita)

    return rx_new, ry_new, vx_new, vy_new


def metodo_Euler(yold, t, dt, N):
    '''
    Método de Euler

    Parameters
    ----------
    yold (ndarray de dimensión 4N): vector de posiciones y velocidades de las partículas en el paso de tiempo anterior
    t (float): tiempo en el paso de tiempo anterior
    dt (float): paso temporal
    N (int): nro de partículas

    Returns
    -------
    ynew (ndarray de dimensión 4N): vector de posiciones y velocidades de las partículas en el paso de tiempo siguiente
    '''
    ynew = yold + dt*f(yold, N)
    return ynew

def metodo_Verlet(yold, t, dt, N):
    '''
    Método de Verlet

    Parameters
    ----------
    yold (ndarray de dimensión 4N): vector de posiciones y velocidades de las partículas en el paso de tiempo anterior
    t (float): tiempo en el paso de tiempo anterior
    dt (float): paso temporal
    N (int): nro de partículas

    Returns
    -------
    ynew (ndarray de dimensión 4N): vector de posiciones y velocidades de las partículas en el paso de tiempo siguiente

    Nota: el esquema numérico está bien definido en el apunte de Física Computacional (FISCOM)
    '''
    
    #Calculo el vector de fuerzas
    dydt = f(yold, N) 
    F_vec = dydt[2*N:]

    #Asigno el vector de posiciones
    r_vec = yold[:2*N]
    #Calculo la posición en el siguiente paso de tiempo
    r_vec_new = r_vec + yold[2*N:4*N]*dt + 1/2*dt**2*F_vec

    #Calculo la fuerza en el siguiente paso de tiempo
    ynew_partial = np.concatenate((r_vec_new, yold[2*N:])) #corrijo solo r_vec

    dydt_new = f(ynew_partial, N)
    F_vec_new = dydt_new[2*N:]

    #Calculo la velocidad en el siguiente paso de tiempo
    v_vec_new = yold[2*N:] + 1/2*dt*(F_vec + F_vec_new)

    return np.concatenate((r_vec_new, v_vec_new))



def avanzo_dt(y, t, dt, N, metodo):
    '''
    Avanza un paso de tiempo el sistema

    Parameters
    ----------
    y (ndarray de dimensión 4N): vector de posiciones y velocidades de las partículas en el paso anterior
    t (float): tiempo en el paso anterior
    dt (float): paso temporal
    N (int): nro de partículas
    metodo (función): método de integración a utilizar

    Returns
    -------
    ynew (ndarray de dimensión 4N): vector de posiciones y velocidades de las partículas en el paso siguiente
    '''
    #Avanzo un paso de tiempo
    ynew = metodo(y, t, dt, N)

    #Verifico si se cumple la condición de choque
    #Calculo la distancia de cada partícula al origen
    d_vec = distancia_al_origen(ynew[0:2*N], N)

    #Determino todos los índices en los que una partícula superó la distancia R0
    indices = np.where(d_vec>R0)[0]
    #Opero sobre las partículas que chocaron
    if len(indices) > 0:
        for indice in indices:
            #Calculo las variables correspondientes
            rx = ynew[indice]
            ry = ynew[indice+N]
            vx = ynew[indice+2*N]
            vy = ynew[indice+3*N]

            #Rebota
            rx_new, ry_new, vx_new, vy_new = rebote_blando(rx, ry, vx, vy)
            #Añado los nuevos datos en ynew de forma ordenada
            ynew[indice] = rx_new
            ynew[indice+N] = ry_new
            ynew[indice+2*N] = vx_new
            ynew[indice+3*N] = vy_new

    #Corrijo las velocidades para llegar a T0. Al hacer esta corrección se deja de conservar la energía cinética
    ynew[2*N:3*N], ynew[3*N:4*N] = correccion_Temperatura(ynew[2*N:3*N], ynew[3*N:4*N])

    return ynew

# %%
def savetxt_append(filename, array, append = True):
    '''
    Guarda array en filename en formato txt. Se puede hacer append de los datos o no

    Parameters
    ----------
    filename (str): nombre del archivo con terminación ".txt"
    array (ndarray): array a guardar
    append (bool): si se quiere hacer append de los datos o no   
    '''
    if append == True:
        with open(filename, "ab") as f:
            # f.write(b"\n")
            #Save array as row
            np.savetxt(f, [array], delimiter = "\t")
    else:
        with open(filename, "wb") as f:
            # f.write(b"\n")
            np.savetxt(f, [array], delimiter = "\t")

# %% [markdown]
# ## Solución numérica

# %%
#Hago una simulación
N = 20 #Nro de partículas
dt = 1e-5 #En 1e-1 ya genera problemas. Las partículas salen de la circunferencia. A modo gral, a mayor N, menor dt
n_pasos = 100*100*10*10 #20000*5*10
guardo_cada = 100 #Cada cuántos pasos de tiempo se guardarán los datos



y0 = condiciones_iniciales(N)
y = y0.copy()
t = 0

#Nombres de archivos
files = ["resultados/py_cpu_pos_x.txt", "resultados/py_cpu_pos_y.txt", "resultados/py_cpu_vel_x.txt", "resultados/py_cpu_vel_y.txt"]


#Inicializo
for i in range(n_pasos):
    if i%guardo_cada== 0:
        print(f"t = {round(t,2)}\tEvolución al {round(i/n_pasos*100,2)}%")

    t += dt
    if i % guardo_cada == 0:

        #Guardo datos
        for j in range(4):
            #Guardar array separado por comma
            savetxt_append(files[j], y[j*N:(j+1)*N], False if i == 0 else True)
    y = avanzo_dt(y, t, dt, N, metodo_Verlet)
# Out:
# t = 0	Evolución al 0.0%
# t = 0.0	Evolución al 0.01%
# t = 0.0	Evolución al 0.02%
# t = 0.0	Evolución al 0.03%
# t = 0.0	Evolución al 0.04%
# t = 0.0	Evolución al 0.05%
# t = 0.01	Evolución al 0.06%
# t = 0.01	Evolución al 0.07%
# t = 0.01	Evolución al 0.08%
# t = 0.01	Evolución al 0.09%
# t = 0.01	Evolución al 0.1%
# t = 0.01	Evolución al 0.11%
# t = 0.01	Evolución al 0.12%
# t = 0.01	Evolución al 0.13%
# t = 0.01	Evolución al 0.14%
# t = 0.01	Evolución al 0.15%
# t = 0.02	Evolución al 0.16%
# t = 0.02	Evolución al 0.17%
# t = 0.02	Evolución al 0.18%
# t = 0.02	Evolución al 0.19%
# t = 0.02	Evolución al 0.2%
# t = 0.02	Evolución al 0.21%
# t = 0.02	Evolución al 0.22%
# t = 0.02	Evolución al 0.23%
# t = 0.02	Evolución al 0.24%
# t = 0.02	Evolución al 0.25%
# t = 0.03	Evolución al 0.26%
# t = 0.03	Evolución al 0.27%
# t = 0.03	Evolución al 0.28%
# t = 0.03	Evolución al 0.29%
# t = 0.03	Evolución al 0.3%
# t = 0.03	Evolución al 0.31%
# t = 0.03	Evolución al 0.32%
# t = 0.03	Evolución al 0.33%
# t = 0.03	Evolución al 0.34%
# t = 0.04	Evolución al 0.35%
# t = 0.04	Evolución al 0.36%
# t = 0.04	Evolución al 0.37%
# t = 0.04	Evolución al 0.38%
# t = 0.04	Evolución al 0.39%
# t = 0.04	Evolución al 0.4%
# t = 0.04	Evolución al 0.41%
# t = 0.04	Evolución al 0.42%
# t = 0.04	Evolución al 0.43%
# t = 0.04	Evolución al 0.44%
# t = 0.05	Evolución al 0.45%
# t = 0.05	Evolución al 0.46%
# t = 0.05	Evolución al 0.47%
# t = 0.05	Evolución al 0.48%
# t = 0.05	Evolución al 0.49%
# t = 0.05	Evolución al 0.5%
# t = 0.05	Evolución al 0.51%
# t = 0.05	Evolución al 0.52%
# t = 0.05	Evolución al 0.53%
# t = 0.05	Evolución al 0.54%
# t = 0.06	Evolución al 0.55%
# t = 0.06	Evolución al 0.56%
# t = 0.06	Evolución al 0.57%
# t = 0.06	Evolución al 0.58%
# t = 0.06	Evolución al 0.59%
# t = 0.06	Evolución al 0.6%
# t = 0.06	Evolución al 0.61%
# t = 0.06	Evolución al 0.62%
# t = 0.06	Evolución al 0.63%
# t = 0.06	Evolución al 0.64%
# t = 0.07	Evolución al 0.65%
# t = 0.07	Evolución al 0.66%
# t = 0.07	Evolución al 0.67%
# t = 0.07	Evolución al 0.68%
# t = 0.07	Evolución al 0.69%
# t = 0.07	Evolución al 0.7%
# t = 0.07	Evolución al 0.71%
# t = 0.07	Evolución al 0.72%
# t = 0.07	Evolución al 0.73%
# t = 0.07	Evolución al 0.74%
# t = 0.08	Evolución al 0.75%
# t = 0.08	Evolución al 0.76%
# t = 0.08	Evolución al 0.77%
# t = 0.08	Evolución al 0.78%
# t = 0.08	Evolución al 0.79%
# t = 0.08	Evolución al 0.8%
# t = 0.08	Evolución al 0.81%
# t = 0.08	Evolución al 0.82%
# t = 0.08	Evolución al 0.83%
# t = 0.08	Evolución al 0.84%
# t = 0.08	Evolución al 0.85%
# t = 0.09	Evolución al 0.86%
# t = 0.09	Evolución al 0.87%
# t = 0.09	Evolución al 0.88%
# t = 0.09	Evolución al 0.89%
# t = 0.09	Evolución al 0.9%
# t = 0.09	Evolución al 0.91%
# t = 0.09	Evolución al 0.92%
# t = 0.09	Evolución al 0.93%
# t = 0.09	Evolución al 0.94%
# t = 0.09	Evolución al 0.95%
# t = 0.1	Evolución al 0.96%
# t = 0.1	Evolución al 0.97%
# t = 0.1	Evolución al 0.98%
# t = 0.1	Evolución al 0.99%
# t = 0.1	Evolución al 1.0%
# t = 0.1	Evolución al 1.01%
# t = 0.1	Evolución al 1.02%
# t = 0.1	Evolución al 1.03%
# t = 0.1	Evolución al 1.04%
# t = 0.1	Evolución al 1.05%
# t = 0.11	Evolución al 1.06%
# t = 0.11	Evolución al 1.07%
# t = 0.11	Evolución al 1.08%
# t = 0.11	Evolución al 1.09%
# t = 0.11	Evolución al 1.1%
# t = 0.11	Evolución al 1.11%
# t = 0.11	Evolución al 1.12%
# t = 0.11	Evolución al 1.13%
# t = 0.11	Evolución al 1.14%
# t = 0.11	Evolución al 1.15%
# t = 0.12	Evolución al 1.16%
# t = 0.12	Evolución al 1.17%
# t = 0.12	Evolución al 1.18%
# t = 0.12	Evolución al 1.19%
# t = 0.12	Evolución al 1.2%
# t = 0.12	Evolución al 1.21%
# t = 0.12	Evolución al 1.22%
# t = 0.12	Evolución al 1.23%
# t = 0.12	Evolución al 1.24%
# t = 0.12	Evolución al 1.25%
# t = 0.13	Evolución al 1.26%
# t = 0.13	Evolución al 1.27%
# t = 0.13	Evolución al 1.28%
# t = 0.13	Evolución al 1.29%
# t = 0.13	Evolución al 1.3%
# t = 0.13	Evolución al 1.31%
# t = 0.13	Evolución al 1.32%
# t = 0.13	Evolución al 1.33%
# t = 0.13	Evolución al 1.34%
# t = 0.13	Evolución al 1.35%
# t = 0.14	Evolución al 1.36%
# t = 0.14	Evolución al 1.37%
# t = 0.14	Evolución al 1.38%
# t = 0.14	Evolución al 1.39%
# t = 0.14	Evolución al 1.4%
# t = 0.14	Evolución al 1.41%
# t = 0.14	Evolución al 1.42%
# t = 0.14	Evolución al 1.43%
# t = 0.14	Evolución al 1.44%
# t = 0.15	Evolución al 1.45%
# t = 0.15	Evolución al 1.46%
# t = 0.15	Evolución al 1.47%
# t = 0.15	Evolución al 1.48%
# t = 0.15	Evolución al 1.49%
# t = 0.15	Evolución al 1.5%
# t = 0.15	Evolución al 1.51%
# t = 0.15	Evolución al 1.52%
# t = 0.15	Evolución al 1.53%
# t = 0.15	Evolución al 1.54%
# t = 0.16	Evolución al 1.55%
# t = 0.16	Evolución al 1.56%
# t = 0.16	Evolución al 1.57%
# t = 0.16	Evolución al 1.58%
# t = 0.16	Evolución al 1.59%
# t = 0.16	Evolución al 1.6%
# t = 0.16	Evolución al 1.61%
# t = 0.16	Evolución al 1.62%
# t = 0.16	Evolución al 1.63%
# t = 0.16	Evolución al 1.64%
# t = 0.17	Evolución al 1.65%
# t = 0.17	Evolución al 1.66%
# t = 0.17	Evolución al 1.67%
# t = 0.17	Evolución al 1.68%
# t = 0.17	Evolución al 1.69%
# t = 0.17	Evolución al 1.7%
# t = 0.17	Evolución al 1.71%
# t = 0.17	Evolución al 1.72%
# t = 0.17	Evolución al 1.73%
# t = 0.17	Evolución al 1.74%
# t = 0.18	Evolución al 1.75%
# t = 0.18	Evolución al 1.76%
# t = 0.18	Evolución al 1.77%
# t = 0.18	Evolución al 1.78%
# t = 0.18	Evolución al 1.79%
# t = 0.18	Evolución al 1.8%
# t = 0.18	Evolución al 1.81%
# t = 0.18	Evolución al 1.82%
# t = 0.18	Evolución al 1.83%
# t = 0.18	Evolución al 1.84%
# t = 0.19	Evolución al 1.85%
# t = 0.19	Evolución al 1.86%
# t = 0.19	Evolución al 1.87%
# t = 0.19	Evolución al 1.88%
# t = 0.19	Evolución al 1.89%
# t = 0.19	Evolución al 1.9%
# t = 0.19	Evolución al 1.91%
# t = 0.19	Evolución al 1.92%
# t = 0.19	Evolución al 1.93%
# t = 0.19	Evolución al 1.94%
# t = 0.2	Evolución al 1.95%
# t = 0.2	Evolución al 1.96%
# t = 0.2	Evolución al 1.97%
# t = 0.2	Evolución al 1.98%
# t = 0.2	Evolución al 1.99%
# t = 0.2	Evolución al 2.0%
# t = 0.2	Evolución al 2.01%
# t = 0.2	Evolución al 2.02%
# t = 0.2	Evolución al 2.03%
# t = 0.2	Evolución al 2.04%
# t = 0.21	Evolución al 2.05%
# t = 0.21	Evolución al 2.06%
# t = 0.21	Evolución al 2.07%
# t = 0.21	Evolución al 2.08%
# t = 0.21	Evolución al 2.09%
# t = 0.21	Evolución al 2.1%
# t = 0.21	Evolución al 2.11%
# t = 0.21	Evolución al 2.12%
# t = 0.21	Evolución al 2.13%
# t = 0.21	Evolución al 2.14%
# t = 0.22	Evolución al 2.15%
# t = 0.22	Evolución al 2.16%
# t = 0.22	Evolución al 2.17%
# t = 0.22	Evolución al 2.18%
# t = 0.22	Evolución al 2.19%
# t = 0.22	Evolución al 2.2%
# t = 0.22	Evolución al 2.21%
# t = 0.22	Evolución al 2.22%
# t = 0.22	Evolución al 2.23%
# t = 0.22	Evolución al 2.24%
# t = 0.23	Evolución al 2.25%
# t = 0.23	Evolución al 2.26%
# t = 0.23	Evolución al 2.27%
# t = 0.23	Evolución al 2.28%
# t = 0.23	Evolución al 2.29%
# t = 0.23	Evolución al 2.3%
# t = 0.23	Evolución al 2.31%
# t = 0.23	Evolución al 2.32%
# t = 0.23	Evolución al 2.33%
# t = 0.23	Evolución al 2.34%
# t = 0.24	Evolución al 2.35%
# t = 0.24	Evolución al 2.36%
# t = 0.24	Evolución al 2.37%
# t = 0.24	Evolución al 2.38%
# t = 0.24	Evolución al 2.39%
# t = 0.24	Evolución al 2.4%
# t = 0.24	Evolución al 2.41%
# t = 0.24	Evolución al 2.42%
# t = 0.24	Evolución al 2.43%
# t = 0.24	Evolución al 2.44%
# t = 0.25	Evolución al 2.45%
# t = 0.25	Evolución al 2.46%
# t = 0.25	Evolución al 2.47%
# t = 0.25	Evolución al 2.48%
# t = 0.25	Evolución al 2.49%
# t = 0.25	Evolución al 2.5%
# t = 0.25	Evolución al 2.51%
# t = 0.25	Evolución al 2.52%
# t = 0.25	Evolución al 2.53%
# t = 0.25	Evolución al 2.54%
# t = 0.26	Evolución al 2.55%
# t = 0.26	Evolución al 2.56%
# t = 0.26	Evolución al 2.57%
# t = 0.26	Evolución al 2.58%
# t = 0.26	Evolución al 2.59%
# t = 0.26	Evolución al 2.6%
# t = 0.26	Evolución al 2.61%
# t = 0.26	Evolución al 2.62%
# t = 0.26	Evolución al 2.63%
# t = 0.26	Evolución al 2.64%
# t = 0.27	Evolución al 2.65%
# t = 0.27	Evolución al 2.66%
# t = 0.27	Evolución al 2.67%
# t = 0.27	Evolución al 2.68%
# t = 0.27	Evolución al 2.69%
# t = 0.27	Evolución al 2.7%
# t = 0.27	Evolución al 2.71%
# t = 0.27	Evolución al 2.72%
# t = 0.27	Evolución al 2.73%
# t = 0.27	Evolución al 2.74%
# t = 0.28	Evolución al 2.75%
# t = 0.28	Evolución al 2.76%
# t = 0.28	Evolución al 2.77%
# t = 0.28	Evolución al 2.78%
# t = 0.28	Evolución al 2.79%
# t = 0.28	Evolución al 2.8%
# t = 0.28	Evolución al 2.81%
# t = 0.28	Evolución al 2.82%
# t = 0.28	Evolución al 2.83%
# t = 0.28	Evolución al 2.84%
# t = 0.29	Evolución al 2.85%
# t = 0.29	Evolución al 2.86%
# t = 0.29	Evolución al 2.87%
# t = 0.29	Evolución al 2.88%
# t = 0.29	Evolución al 2.89%
# t = 0.29	Evolución al 2.9%
# t = 0.29	Evolución al 2.91%
# t = 0.29	Evolución al 2.92%
# t = 0.29	Evolución al 2.93%
# t = 0.29	Evolución al 2.94%
# t = 0.3	Evolución al 2.95%
# t = 0.3	Evolución al 2.96%
# t = 0.3	Evolución al 2.97%
# t = 0.3	Evolución al 2.98%
# t = 0.3	Evolución al 2.99%
# t = 0.3	Evolución al 3.0%
# t = 0.3	Evolución al 3.01%
# t = 0.3	Evolución al 3.02%
# t = 0.3	Evolución al 3.03%
# t = 0.3	Evolución al 3.04%
# t = 0.31	Evolución al 3.05%
# t = 0.31	Evolución al 3.06%
# t = 0.31	Evolución al 3.07%
# t = 0.31	Evolución al 3.08%
# t = 0.31	Evolución al 3.09%
# t = 0.31	Evolución al 3.1%
# t = 0.31	Evolución al 3.11%
# t = 0.31	Evolución al 3.12%
# t = 0.31	Evolución al 3.13%
# t = 0.31	Evolución al 3.14%
# t = 0.32	Evolución al 3.15%
# t = 0.32	Evolución al 3.16%
# t = 0.32	Evolución al 3.17%
# t = 0.32	Evolución al 3.18%
# t = 0.32	Evolución al 3.19%
# t = 0.32	Evolución al 3.2%
# t = 0.32	Evolución al 3.21%
# t = 0.32	Evolución al 3.22%
# t = 0.32	Evolución al 3.23%
# t = 0.32	Evolución al 3.24%
# t = 0.33	Evolución al 3.25%
# t = 0.33	Evolución al 3.26%
# t = 0.33	Evolución al 3.27%
# t = 0.33	Evolución al 3.28%
# t = 0.33	Evolución al 3.29%
# t = 0.33	Evolución al 3.3%
# t = 0.33	Evolución al 3.31%
# t = 0.33	Evolución al 3.32%
# t = 0.33	Evolución al 3.33%
# t = 0.33	Evolución al 3.34%
# t = 0.34	Evolución al 3.35%
# t = 0.34	Evolución al 3.36%
# t = 0.34	Evolución al 3.37%
# t = 0.34	Evolución al 3.38%
# t = 0.34	Evolución al 3.39%
# t = 0.34	Evolución al 3.4%
# t = 0.34	Evolución al 3.41%
# t = 0.34	Evolución al 3.42%
# t = 0.34	Evolución al 3.43%
# t = 0.34	Evolución al 3.44%
# t = 0.35	Evolución al 3.45%
# t = 0.35	Evolución al 3.46%
# t = 0.35	Evolución al 3.47%
# t = 0.35	Evolución al 3.48%
# t = 0.35	Evolución al 3.49%
# t = 0.35	Evolución al 3.5%
# t = 0.35	Evolución al 3.51%
# t = 0.35	Evolución al 3.52%
# t = 0.35	Evolución al 3.53%
# t = 0.35	Evolución al 3.54%
# t = 0.36	Evolución al 3.55%
# t = 0.36	Evolución al 3.56%
# t = 0.36	Evolución al 3.57%
# t = 0.36	Evolución al 3.58%
# t = 0.36	Evolución al 3.59%
# t = 0.36	Evolución al 3.6%
# t = 0.36	Evolución al 3.61%
# t = 0.36	Evolución al 3.62%
# t = 0.36	Evolución al 3.63%
# t = 0.36	Evolución al 3.64%
# t = 0.37	Evolución al 3.65%
# t = 0.37	Evolución al 3.66%
# t = 0.37	Evolución al 3.67%
# t = 0.37	Evolución al 3.68%
# t = 0.37	Evolución al 3.69%
# t = 0.37	Evolución al 3.7%
# t = 0.37	Evolución al 3.71%
# t = 0.37	Evolución al 3.72%
# t = 0.37	Evolución al 3.73%
# t = 0.37	Evolución al 3.74%
# t = 0.38	Evolución al 3.75%
# t = 0.38	Evolución al 3.76%
# t = 0.38	Evolución al 3.77%
# t = 0.38	Evolución al 3.78%
# t = 0.38	Evolución al 3.79%
# t = 0.38	Evolución al 3.8%
# t = 0.38	Evolución al 3.81%
# t = 0.38	Evolución al 3.82%
# t = 0.38	Evolución al 3.83%
# t = 0.38	Evolución al 3.84%
# t = 0.39	Evolución al 3.85%
# t = 0.39	Evolución al 3.86%
# t = 0.39	Evolución al 3.87%
# t = 0.39	Evolución al 3.88%
# t = 0.39	Evolución al 3.89%
# t = 0.39	Evolución al 3.9%
# t = 0.39	Evolución al 3.91%
# t = 0.39	Evolución al 3.92%
# t = 0.39	Evolución al 3.93%
# t = 0.39	Evolución al 3.94%
# t = 0.4	Evolución al 3.95%
# t = 0.4	Evolución al 3.96%
# t = 0.4	Evolución al 3.97%
# t = 0.4	Evolución al 3.98%
# t = 0.4	Evolución al 3.99%
# t = 0.4	Evolución al 4.0%
# t = 0.4	Evolución al 4.01%
# t = 0.4	Evolución al 4.02%
# t = 0.4	Evolución al 4.03%
# t = 0.4	Evolución al 4.04%
# t = 0.41	Evolución al 4.05%
# t = 0.41	Evolución al 4.06%
# t = 0.41	Evolución al 4.07%
# t = 0.41	Evolución al 4.08%
# t = 0.41	Evolución al 4.09%
# t = 0.41	Evolución al 4.1%
# t = 0.41	Evolución al 4.11%
# t = 0.41	Evolución al 4.12%
# t = 0.41	Evolución al 4.13%
# t = 0.41	Evolución al 4.14%
# t = 0.42	Evolución al 4.15%
# t = 0.42	Evolución al 4.16%
# t = 0.42	Evolución al 4.17%
# t = 0.42	Evolución al 4.18%
# t = 0.42	Evolución al 4.19%
# t = 0.42	Evolución al 4.2%
# t = 0.42	Evolución al 4.21%
# t = 0.42	Evolución al 4.22%
# t = 0.42	Evolución al 4.23%
# t = 0.42	Evolución al 4.24%
# t = 0.43	Evolución al 4.25%
# t = 0.43	Evolución al 4.26%
# t = 0.43	Evolución al 4.27%
# t = 0.43	Evolución al 4.28%
# t = 0.43	Evolución al 4.29%
# t = 0.43	Evolución al 4.3%
# t = 0.43	Evolución al 4.31%
# t = 0.43	Evolución al 4.32%
# t = 0.43	Evolución al 4.33%
# t = 0.43	Evolución al 4.34%
# t = 0.44	Evolución al 4.35%
# t = 0.44	Evolución al 4.36%
# t = 0.44	Evolución al 4.37%
# t = 0.44	Evolución al 4.38%
# t = 0.44	Evolución al 4.39%
# t = 0.44	Evolución al 4.4%
# t = 0.44	Evolución al 4.41%
# t = 0.44	Evolución al 4.42%
# t = 0.44	Evolución al 4.43%
# t = 0.44	Evolución al 4.44%
# t = 0.45	Evolución al 4.45%
# t = 0.45	Evolución al 4.46%
# t = 0.45	Evolución al 4.47%
# t = 0.45	Evolución al 4.48%
# t = 0.45	Evolución al 4.49%
# t = 0.45	Evolución al 4.5%
# t = 0.45	Evolución al 4.51%
# t = 0.45	Evolución al 4.52%
# t = 0.45	Evolución al 4.53%
# t = 0.45	Evolución al 4.54%
# t = 0.46	Evolución al 4.55%
# t = 0.46	Evolución al 4.56%
# t = 0.46	Evolución al 4.57%
# t = 0.46	Evolución al 4.58%
# t = 0.46	Evolución al 4.59%
# t = 0.46	Evolución al 4.6%
# t = 0.46	Evolución al 4.61%
# t = 0.46	Evolución al 4.62%
# t = 0.46	Evolución al 4.63%
# t = 0.46	Evolución al 4.64%
# t = 0.47	Evolución al 4.65%
# t = 0.47	Evolución al 4.66%
# t = 0.47	Evolución al 4.67%
# t = 0.47	Evolución al 4.68%
# t = 0.47	Evolución al 4.69%
# t = 0.47	Evolución al 4.7%
# t = 0.47	Evolución al 4.71%
# t = 0.47	Evolución al 4.72%
# t = 0.47	Evolución al 4.73%
# t = 0.47	Evolución al 4.74%
# t = 0.48	Evolución al 4.75%
# t = 0.48	Evolución al 4.76%
# t = 0.48	Evolución al 4.77%
# t = 0.48	Evolución al 4.78%
# t = 0.48	Evolución al 4.79%
# t = 0.48	Evolución al 4.8%
# t = 0.48	Evolución al 4.81%
# t = 0.48	Evolución al 4.82%
# t = 0.48	Evolución al 4.83%
# t = 0.48	Evolución al 4.84%
# t = 0.49	Evolución al 4.85%
# t = 0.49	Evolución al 4.86%
# t = 0.49	Evolución al 4.87%
# t = 0.49	Evolución al 4.88%
# t = 0.49	Evolución al 4.89%
# t = 0.49	Evolución al 4.9%
# t = 0.49	Evolución al 4.91%
# t = 0.49	Evolución al 4.92%
# t = 0.49	Evolución al 4.93%
# t = 0.49	Evolución al 4.94%
# t = 0.5	Evolución al 4.95%
# t = 0.5	Evolución al 4.96%
# t = 0.5	Evolución al 4.97%
# t = 0.5	Evolución al 4.98%
# t = 0.5	Evolución al 4.99%
# t = 0.5	Evolución al 5.0%
# t = 0.5	Evolución al 5.01%
# t = 0.5	Evolución al 5.02%
# t = 0.5	Evolución al 5.03%
# t = 0.5	Evolución al 5.04%
# t = 0.51	Evolución al 5.05%
# t = 0.51	Evolución al 5.06%
# t = 0.51	Evolución al 5.07%
# t = 0.51	Evolución al 5.08%
# t = 0.51	Evolución al 5.09%
# t = 0.51	Evolución al 5.1%
# t = 0.51	Evolución al 5.11%
# t = 0.51	Evolución al 5.12%
# t = 0.51	Evolución al 5.13%
# t = 0.51	Evolución al 5.14%
# t = 0.52	Evolución al 5.15%
# t = 0.52	Evolución al 5.16%
# t = 0.52	Evolución al 5.17%
# t = 0.52	Evolución al 5.18%
# t = 0.52	Evolución al 5.19%
# t = 0.52	Evolución al 5.2%
# t = 0.52	Evolución al 5.21%
# t = 0.52	Evolución al 5.22%
# t = 0.52	Evolución al 5.23%
# t = 0.52	Evolución al 5.24%
# t = 0.53	Evolución al 5.25%
# t = 0.53	Evolución al 5.26%
# t = 0.53	Evolución al 5.27%
# t = 0.53	Evolución al 5.28%
# t = 0.53	Evolución al 5.29%
# t = 0.53	Evolución al 5.3%
# t = 0.53	Evolución al 5.31%
# t = 0.53	Evolución al 5.32%
# t = 0.53	Evolución al 5.33%
# t = 0.53	Evolución al 5.34%
# t = 0.54	Evolución al 5.35%
# t = 0.54	Evolución al 5.36%
# t = 0.54	Evolución al 5.37%
# t = 0.54	Evolución al 5.38%
# t = 0.54	Evolución al 5.39%
# t = 0.54	Evolución al 5.4%
# t = 0.54	Evolución al 5.41%
# t = 0.54	Evolución al 5.42%
# t = 0.54	Evolución al 5.43%
# t = 0.54	Evolución al 5.44%
# t = 0.55	Evolución al 5.45%
# t = 0.55	Evolución al 5.46%
# t = 0.55	Evolución al 5.47%
# t = 0.55	Evolución al 5.48%
# t = 0.55	Evolución al 5.49%
# t = 0.55	Evolución al 5.5%
# t = 0.55	Evolución al 5.51%
# t = 0.55	Evolución al 5.52%
# t = 0.55	Evolución al 5.53%
# t = 0.55	Evolución al 5.54%
# t = 0.56	Evolución al 5.55%
# t = 0.56	Evolución al 5.56%
# t = 0.56	Evolución al 5.57%
# t = 0.56	Evolución al 5.58%
# t = 0.56	Evolución al 5.59%
# t = 0.56	Evolución al 5.6%
# t = 0.56	Evolución al 5.61%
# t = 0.56	Evolución al 5.62%
# t = 0.56	Evolución al 5.63%
# t = 0.56	Evolución al 5.64%
# t = 0.57	Evolución al 5.65%
# t = 0.57	Evolución al 5.66%
# t = 0.57	Evolución al 5.67%
# t = 0.57	Evolución al 5.68%
# t = 0.57	Evolución al 5.69%
# t = 0.57	Evolución al 5.7%
# t = 0.57	Evolución al 5.71%
# t = 0.57	Evolución al 5.72%
# t = 0.57	Evolución al 5.73%
# t = 0.57	Evolución al 5.74%
# t = 0.58	Evolución al 5.75%
# t = 0.58	Evolución al 5.76%
# t = 0.58	Evolución al 5.77%
# t = 0.58	Evolución al 5.78%
# t = 0.58	Evolución al 5.79%
# t = 0.58	Evolución al 5.8%
# t = 0.58	Evolución al 5.81%
# t = 0.58	Evolución al 5.82%
# t = 0.58	Evolución al 5.83%
# t = 0.58	Evolución al 5.84%
# t = 0.58	Evolución al 5.85%
# t = 0.59	Evolución al 5.86%
# t = 0.59	Evolución al 5.87%
# t = 0.59	Evolución al 5.88%
# t = 0.59	Evolución al 5.89%
# t = 0.59	Evolución al 5.9%
# t = 0.59	Evolución al 5.91%
# t = 0.59	Evolución al 5.92%
# t = 0.59	Evolución al 5.93%
# t = 0.59	Evolución al 5.94%
# t = 0.59	Evolución al 5.95%
# t = 0.6	Evolución al 5.96%
# t = 0.6	Evolución al 5.97%
# t = 0.6	Evolución al 5.98%
# t = 0.6	Evolución al 5.99%
# t = 0.6	Evolución al 6.0%
# t = 0.6	Evolución al 6.01%
# t = 0.6	Evolución al 6.02%
# t = 0.6	Evolución al 6.03%
# t = 0.6	Evolución al 6.04%
# t = 0.6	Evolución al 6.05%
# t = 0.61	Evolución al 6.06%
# t = 0.61	Evolución al 6.07%
# t = 0.61	Evolución al 6.08%
# t = 0.61	Evolución al 6.09%
# t = 0.61	Evolución al 6.1%
# t = 0.61	Evolución al 6.11%
# t = 0.61	Evolución al 6.12%
# t = 0.61	Evolución al 6.13%
# t = 0.61	Evolución al 6.14%
# t = 0.61	Evolución al 6.15%
# t = 0.62	Evolución al 6.16%
# t = 0.62	Evolución al 6.17%
# t = 0.62	Evolución al 6.18%
# t = 0.62	Evolución al 6.19%
# t = 0.62	Evolución al 6.2%
# t = 0.62	Evolución al 6.21%
# t = 0.62	Evolución al 6.22%
# t = 0.62	Evolución al 6.23%
# t = 0.62	Evolución al 6.24%
# t = 0.62	Evolución al 6.25%
# t = 0.63	Evolución al 6.26%
# t = 0.63	Evolución al 6.27%
# t = 0.63	Evolución al 6.28%
# t = 0.63	Evolución al 6.29%
# t = 0.63	Evolución al 6.3%
# t = 0.63	Evolución al 6.31%
# t = 0.63	Evolución al 6.32%
# t = 0.63	Evolución al 6.33%
# t = 0.63	Evolución al 6.34%
# t = 0.63	Evolución al 6.35%
# t = 0.64	Evolución al 6.36%
# t = 0.64	Evolución al 6.37%
# t = 0.64	Evolución al 6.38%
# t = 0.64	Evolución al 6.39%
# t = 0.64	Evolución al 6.4%
# t = 0.64	Evolución al 6.41%
# t = 0.64	Evolución al 6.42%
# t = 0.64	Evolución al 6.43%
# t = 0.64	Evolución al 6.44%
# t = 0.64	Evolución al 6.45%
# t = 0.65	Evolución al 6.46%
# t = 0.65	Evolución al 6.47%
# t = 0.65	Evolución al 6.48%
# t = 0.65	Evolución al 6.49%
# t = 0.65	Evolución al 6.5%
# t = 0.65	Evolución al 6.51%
# t = 0.65	Evolución al 6.52%
# t = 0.65	Evolución al 6.53%
# t = 0.65	Evolución al 6.54%
# t = 0.65	Evolución al 6.55%
# t = 0.66	Evolución al 6.56%
# t = 0.66	Evolución al 6.57%
# t = 0.66	Evolución al 6.58%
# t = 0.66	Evolución al 6.59%
# t = 0.66	Evolución al 6.6%
# t = 0.66	Evolución al 6.61%
# t = 0.66	Evolución al 6.62%
# t = 0.66	Evolución al 6.63%
# t = 0.66	Evolución al 6.64%
# t = 0.66	Evolución al 6.65%
# t = 0.67	Evolución al 6.66%
# t = 0.67	Evolución al 6.67%
# t = 0.67	Evolución al 6.68%
# t = 0.67	Evolución al 6.69%
# t = 0.67	Evolución al 6.7%
# t = 0.67	Evolución al 6.71%
# t = 0.67	Evolución al 6.72%
# t = 0.67	Evolución al 6.73%
# t = 0.67	Evolución al 6.74%
# t = 0.67	Evolución al 6.75%
# t = 0.68	Evolución al 6.76%
# t = 0.68	Evolución al 6.77%
# t = 0.68	Evolución al 6.78%
# t = 0.68	Evolución al 6.79%
# t = 0.68	Evolución al 6.8%
# t = 0.68	Evolución al 6.81%
# t = 0.68	Evolución al 6.82%
# t = 0.68	Evolución al 6.83%
# t = 0.68	Evolución al 6.84%
# t = 0.68	Evolución al 6.85%
# t = 0.69	Evolución al 6.86%
# t = 0.69	Evolución al 6.87%
# t = 0.69	Evolución al 6.88%
# t = 0.69	Evolución al 6.89%
# t = 0.69	Evolución al 6.9%
# t = 0.69	Evolución al 6.91%
# t = 0.69	Evolución al 6.92%
# t = 0.69	Evolución al 6.93%
# t = 0.69	Evolución al 6.94%
# t = 0.69	Evolución al 6.95%
# t = 0.7	Evolución al 6.96%
# t = 0.7	Evolución al 6.97%
# t = 0.7	Evolución al 6.98%
# t = 0.7	Evolución al 6.99%
# t = 0.7	Evolución al 7.0%
# t = 0.7	Evolución al 7.01%
# t = 0.7	Evolución al 7.02%
# t = 0.7	Evolución al 7.03%
# t = 0.7	Evolución al 7.04%
# t = 0.7	Evolución al 7.05%
# t = 0.71	Evolución al 7.06%
# t = 0.71	Evolución al 7.07%
# t = 0.71	Evolución al 7.08%
# t = 0.71	Evolución al 7.09%
# t = 0.71	Evolución al 7.1%
# t = 0.71	Evolución al 7.11%
# t = 0.71	Evolución al 7.12%
# t = 0.71	Evolución al 7.13%
# t = 0.71	Evolución al 7.14%
# t = 0.71	Evolución al 7.15%
# t = 0.72	Evolución al 7.16%
# t = 0.72	Evolución al 7.17%
# t = 0.72	Evolución al 7.18%
# t = 0.72	Evolución al 7.19%
# t = 0.72	Evolución al 7.2%
# t = 0.72	Evolución al 7.21%
# t = 0.72	Evolución al 7.22%
# t = 0.72	Evolución al 7.23%
# t = 0.72	Evolución al 7.24%
# t = 0.72	Evolución al 7.25%
# t = 0.73	Evolución al 7.26%
# t = 0.73	Evolución al 7.27%
# t = 0.73	Evolución al 7.28%
# t = 0.73	Evolución al 7.29%
# t = 0.73	Evolución al 7.3%
# t = 0.73	Evolución al 7.31%
# t = 0.73	Evolución al 7.32%
# t = 0.73	Evolución al 7.33%
# t = 0.73	Evolución al 7.34%
# t = 0.73	Evolución al 7.35%
# t = 0.74	Evolución al 7.36%
# t = 0.74	Evolución al 7.37%
# t = 0.74	Evolución al 7.38%
# t = 0.74	Evolución al 7.39%
# t = 0.74	Evolución al 7.4%
# t = 0.74	Evolución al 7.41%
# t = 0.74	Evolución al 7.42%
# t = 0.74	Evolución al 7.43%
# t = 0.74	Evolución al 7.44%
# t = 0.74	Evolución al 7.45%
# t = 0.75	Evolución al 7.46%
# t = 0.75	Evolución al 7.47%
# t = 0.75	Evolución al 7.48%
# t = 0.75	Evolución al 7.49%
# t = 0.75	Evolución al 7.5%
# t = 0.75	Evolución al 7.51%
# t = 0.75	Evolución al 7.52%
# t = 0.75	Evolución al 7.53%
# t = 0.75	Evolución al 7.54%
# t = 0.75	Evolución al 7.55%
# t = 0.76	Evolución al 7.56%
# t = 0.76	Evolución al 7.57%
# t = 0.76	Evolución al 7.58%
# t = 0.76	Evolución al 7.59%
# t = 0.76	Evolución al 7.6%
# t = 0.76	Evolución al 7.61%
# t = 0.76	Evolución al 7.62%
# t = 0.76	Evolución al 7.63%
# t = 0.76	Evolución al 7.64%
# t = 0.76	Evolución al 7.65%
# t = 0.77	Evolución al 7.66%
# t = 0.77	Evolución al 7.67%
# t = 0.77	Evolución al 7.68%
# t = 0.77	Evolución al 7.69%
# t = 0.77	Evolución al 7.7%
# t = 0.77	Evolución al 7.71%
# t = 0.77	Evolución al 7.72%
# t = 0.77	Evolución al 7.73%
# t = 0.77	Evolución al 7.74%
# t = 0.77	Evolución al 7.75%
# t = 0.78	Evolución al 7.76%
# t = 0.78	Evolución al 7.77%
# t = 0.78	Evolución al 7.78%
# t = 0.78	Evolución al 7.79%
# t = 0.78	Evolución al 7.8%
# t = 0.78	Evolución al 7.81%
# t = 0.78	Evolución al 7.82%
# t = 0.78	Evolución al 7.83%
# t = 0.78	Evolución al 7.84%
# t = 0.78	Evolución al 7.85%
# t = 0.79	Evolución al 7.86%
# t = 0.79	Evolución al 7.87%
# t = 0.79	Evolución al 7.88%
# t = 0.79	Evolución al 7.89%
# t = 0.79	Evolución al 7.9%
# t = 0.79	Evolución al 7.91%
# t = 0.79	Evolución al 7.92%
# t = 0.79	Evolución al 7.93%
# t = 0.79	Evolución al 7.94%
# t = 0.79	Evolución al 7.95%
# t = 0.8	Evolución al 7.96%
# t = 0.8	Evolución al 7.97%
# t = 0.8	Evolución al 7.98%
# t = 0.8	Evolución al 7.99%
# t = 0.8	Evolución al 8.0%
# t = 0.8	Evolución al 8.01%
# t = 0.8	Evolución al 8.02%
# t = 0.8	Evolución al 8.03%
# t = 0.8	Evolución al 8.04%
# t = 0.8	Evolución al 8.05%
# t = 0.81	Evolución al 8.06%
# t = 0.81	Evolución al 8.07%
# t = 0.81	Evolución al 8.08%
# t = 0.81	Evolución al 8.09%
# t = 0.81	Evolución al 8.1%
# t = 0.81	Evolución al 8.11%
# t = 0.81	Evolución al 8.12%
# t = 0.81	Evolución al 8.13%
# t = 0.81	Evolución al 8.14%
# t = 0.81	Evolución al 8.15%
# t = 0.82	Evolución al 8.16%
# t = 0.82	Evolución al 8.17%
# t = 0.82	Evolución al 8.18%
# t = 0.82	Evolución al 8.19%
# t = 0.82	Evolución al 8.2%
# t = 0.82	Evolución al 8.21%
# t = 0.82	Evolución al 8.22%
# t = 0.82	Evolución al 8.23%
# t = 0.82	Evolución al 8.24%
# t = 0.82	Evolución al 8.25%
# t = 0.83	Evolución al 8.26%
# t = 0.83	Evolución al 8.27%
# t = 0.83	Evolución al 8.28%
# t = 0.83	Evolución al 8.29%
# t = 0.83	Evolución al 8.3%
# t = 0.83	Evolución al 8.31%
# t = 0.83	Evolución al 8.32%
# t = 0.83	Evolución al 8.33%
# t = 0.83	Evolución al 8.34%
# t = 0.83	Evolución al 8.35%
# t = 0.84	Evolución al 8.36%
# t = 0.84	Evolución al 8.37%
# t = 0.84	Evolución al 8.38%
# t = 0.84	Evolución al 8.39%
# t = 0.84	Evolución al 8.4%
# t = 0.84	Evolución al 8.41%
# t = 0.84	Evolución al 8.42%
# t = 0.84	Evolución al 8.43%
# t = 0.84	Evolución al 8.44%
# t = 0.84	Evolución al 8.45%
# t = 0.85	Evolución al 8.46%
# t = 0.85	Evolución al 8.47%
# t = 0.85	Evolución al 8.48%
# t = 0.85	Evolución al 8.49%
# t = 0.85	Evolución al 8.5%
# t = 0.85	Evolución al 8.51%
# t = 0.85	Evolución al 8.52%
# t = 0.85	Evolución al 8.53%
# t = 0.85	Evolución al 8.54%
# t = 0.85	Evolución al 8.55%
# t = 0.86	Evolución al 8.56%
# t = 0.86	Evolución al 8.57%
# t = 0.86	Evolución al 8.58%
# t = 0.86	Evolución al 8.59%
# t = 0.86	Evolución al 8.6%
# t = 0.86	Evolución al 8.61%
# t = 0.86	Evolución al 8.62%
# t = 0.86	Evolución al 8.63%
# t = 0.86	Evolución al 8.64%
# t = 0.86	Evolución al 8.65%
# t = 0.87	Evolución al 8.66%
# t = 0.87	Evolución al 8.67%
# t = 0.87	Evolución al 8.68%
# t = 0.87	Evolución al 8.69%
# t = 0.87	Evolución al 8.7%
# t = 0.87	Evolución al 8.71%
# t = 0.87	Evolución al 8.72%
# t = 0.87	Evolución al 8.73%
# t = 0.87	Evolución al 8.74%
# t = 0.87	Evolución al 8.75%
# t = 0.88	Evolución al 8.76%
# t = 0.88	Evolución al 8.77%
# t = 0.88	Evolución al 8.78%
# t = 0.88	Evolución al 8.79%
# t = 0.88	Evolución al 8.8%
# t = 0.88	Evolución al 8.81%
# t = 0.88	Evolución al 8.82%
# t = 0.88	Evolución al 8.83%
# t = 0.88	Evolución al 8.84%
# t = 0.88	Evolución al 8.85%
# t = 0.89	Evolución al 8.86%
# t = 0.89	Evolución al 8.87%
# t = 0.89	Evolución al 8.88%
# t = 0.89	Evolución al 8.89%
# t = 0.89	Evolución al 8.9%
# t = 0.89	Evolución al 8.91%
# t = 0.89	Evolución al 8.92%
# t = 0.89	Evolución al 8.93%
# t = 0.89	Evolución al 8.94%
# t = 0.89	Evolución al 8.95%
# t = 0.9	Evolución al 8.96%
# t = 0.9	Evolución al 8.97%
# t = 0.9	Evolución al 8.98%
# t = 0.9	Evolución al 8.99%
# t = 0.9	Evolución al 9.0%
# t = 0.9	Evolución al 9.01%
# t = 0.9	Evolución al 9.02%
# t = 0.9	Evolución al 9.03%
# t = 0.9	Evolución al 9.04%
# t = 0.9	Evolución al 9.05%
# t = 0.91	Evolución al 9.06%
# t = 0.91	Evolución al 9.07%
# t = 0.91	Evolución al 9.08%
# t = 0.91	Evolución al 9.09%
# t = 0.91	Evolución al 9.1%
# t = 0.91	Evolución al 9.11%
# t = 0.91	Evolución al 9.12%
# t = 0.91	Evolución al 9.13%
# t = 0.91	Evolución al 9.14%
# t = 0.91	Evolución al 9.15%
# t = 0.92	Evolución al 9.16%
# t = 0.92	Evolución al 9.17%
# t = 0.92	Evolución al 9.18%
# t = 0.92	Evolución al 9.19%
# t = 0.92	Evolución al 9.2%
# t = 0.92	Evolución al 9.21%
# t = 0.92	Evolución al 9.22%
# t = 0.92	Evolución al 9.23%
# t = 0.92	Evolución al 9.24%
# t = 0.92	Evolución al 9.25%
# t = 0.93	Evolución al 9.26%
# t = 0.93	Evolución al 9.27%
# t = 0.93	Evolución al 9.28%
# t = 0.93	Evolución al 9.29%
# t = 0.93	Evolución al 9.3%
# t = 0.93	Evolución al 9.31%
# t = 0.93	Evolución al 9.32%
# t = 0.93	Evolución al 9.33%
# t = 0.93	Evolución al 9.34%
# t = 0.93	Evolución al 9.35%
# t = 0.94	Evolución al 9.36%
# t = 0.94	Evolución al 9.37%
# t = 0.94	Evolución al 9.38%
# t = 0.94	Evolución al 9.39%
# t = 0.94	Evolución al 9.4%
# t = 0.94	Evolución al 9.41%
# t = 0.94	Evolución al 9.42%
# t = 0.94	Evolución al 9.43%
# t = 0.94	Evolución al 9.44%
# t = 0.94	Evolución al 9.45%
# t = 0.95	Evolución al 9.46%
# t = 0.95	Evolución al 9.47%
# t = 0.95	Evolución al 9.48%
# t = 0.95	Evolución al 9.49%
# t = 0.95	Evolución al 9.5%
# t = 0.95	Evolución al 9.51%
# t = 0.95	Evolución al 9.52%
# t = 0.95	Evolución al 9.53%
# t = 0.95	Evolución al 9.54%
# t = 0.95	Evolución al 9.55%
# t = 0.96	Evolución al 9.56%
# t = 0.96	Evolución al 9.57%
# t = 0.96	Evolución al 9.58%
# t = 0.96	Evolución al 9.59%
# t = 0.96	Evolución al 9.6%
# t = 0.96	Evolución al 9.61%
# t = 0.96	Evolución al 9.62%
# t = 0.96	Evolución al 9.63%
# t = 0.96	Evolución al 9.64%
# t = 0.96	Evolución al 9.65%
# t = 0.97	Evolución al 9.66%
# t = 0.97	Evolución al 9.67%
# t = 0.97	Evolución al 9.68%
# t = 0.97	Evolución al 9.69%
# t = 0.97	Evolución al 9.7%
# t = 0.97	Evolución al 9.71%
# t = 0.97	Evolución al 9.72%
# t = 0.97	Evolución al 9.73%
# t = 0.97	Evolución al 9.74%
# t = 0.97	Evolución al 9.75%
# t = 0.98	Evolución al 9.76%
# t = 0.98	Evolución al 9.77%
# t = 0.98	Evolución al 9.78%
# t = 0.98	Evolución al 9.79%
# t = 0.98	Evolución al 9.8%
# t = 0.98	Evolución al 9.81%
# t = 0.98	Evolución al 9.82%
# t = 0.98	Evolución al 9.83%
# t = 0.98	Evolución al 9.84%
# t = 0.98	Evolución al 9.85%
# t = 0.99	Evolución al 9.86%
# t = 0.99	Evolución al 9.87%
# t = 0.99	Evolución al 9.88%
# t = 0.99	Evolución al 9.89%
# t = 0.99	Evolución al 9.9%
# t = 0.99	Evolución al 9.91%
# t = 0.99	Evolución al 9.92%
# t = 0.99	Evolución al 9.93%
# t = 0.99	Evolución al 9.94%
# t = 0.99	Evolución al 9.95%
# t = 1.0	Evolución al 9.96%
# t = 1.0	Evolución al 9.97%
# t = 1.0	Evolución al 9.98%
# t = 1.0	Evolución al 9.99%
# t = 1.0	Evolución al 10.0%
# t = 1.0	Evolución al 10.01%
# t = 1.0	Evolución al 10.02%
# t = 1.0	Evolución al 10.03%
# t = 1.0	Evolución al 10.04%
# t = 1.0	Evolución al 10.05%
# t = 1.01	Evolución al 10.06%
# t = 1.01	Evolución al 10.07%
# t = 1.01	Evolución al 10.08%
# t = 1.01	Evolución al 10.09%
# t = 1.01	Evolución al 10.1%
# t = 1.01	Evolución al 10.11%
# t = 1.01	Evolución al 10.12%
# t = 1.01	Evolución al 10.13%
# t = 1.01	Evolución al 10.14%
# t = 1.01	Evolución al 10.15%
# t = 1.02	Evolución al 10.16%
# t = 1.02	Evolución al 10.17%
# t = 1.02	Evolución al 10.18%
# t = 1.02	Evolución al 10.19%
# t = 1.02	Evolución al 10.2%
# t = 1.02	Evolución al 10.21%
# t = 1.02	Evolución al 10.22%
# t = 1.02	Evolución al 10.23%
# t = 1.02	Evolución al 10.24%
# t = 1.02	Evolución al 10.25%
# t = 1.03	Evolución al 10.26%
# t = 1.03	Evolución al 10.27%
# t = 1.03	Evolución al 10.28%
# t = 1.03	Evolución al 10.29%
# t = 1.03	Evolución al 10.3%
# t = 1.03	Evolución al 10.31%
# t = 1.03	Evolución al 10.32%
# t = 1.03	Evolución al 10.33%
# t = 1.03	Evolución al 10.34%
# t = 1.03	Evolución al 10.35%
# t = 1.04	Evolución al 10.36%
# t = 1.04	Evolución al 10.37%
# t = 1.04	Evolución al 10.38%
# t = 1.04	Evolución al 10.39%
# t = 1.04	Evolución al 10.4%
# t = 1.04	Evolución al 10.41%
# t = 1.04	Evolución al 10.42%
# t = 1.04	Evolución al 10.43%
# t = 1.04	Evolución al 10.44%
# t = 1.04	Evolución al 10.45%
# t = 1.05	Evolución al 10.46%
# t = 1.05	Evolución al 10.47%
# t = 1.05	Evolución al 10.48%
# t = 1.05	Evolución al 10.49%
# t = 1.05	Evolución al 10.5%
# t = 1.05	Evolución al 10.51%
# t = 1.05	Evolución al 10.52%
# t = 1.05	Evolución al 10.53%
# t = 1.05	Evolución al 10.54%
# t = 1.05	Evolución al 10.55%
# t = 1.06	Evolución al 10.56%
# t = 1.06	Evolución al 10.57%
# t = 1.06	Evolución al 10.58%
# t = 1.06	Evolución al 10.59%
# t = 1.06	Evolución al 10.6%
# t = 1.06	Evolución al 10.61%
# t = 1.06	Evolución al 10.62%
# t = 1.06	Evolución al 10.63%
# t = 1.06	Evolución al 10.64%
# t = 1.06	Evolución al 10.65%
# t = 1.07	Evolución al 10.66%
# t = 1.07	Evolución al 10.67%
# t = 1.07	Evolución al 10.68%
# t = 1.07	Evolución al 10.69%
# t = 1.07	Evolución al 10.7%
# t = 1.07	Evolución al 10.71%
# t = 1.07	Evolución al 10.72%
# t = 1.07	Evolución al 10.73%
# t = 1.07	Evolución al 10.74%
# t = 1.07	Evolución al 10.75%
# t = 1.08	Evolución al 10.76%
# t = 1.08	Evolución al 10.77%
# t = 1.08	Evolución al 10.78%
# t = 1.08	Evolución al 10.79%
# t = 1.08	Evolución al 10.8%
# t = 1.08	Evolución al 10.81%
# t = 1.08	Evolución al 10.82%
# t = 1.08	Evolución al 10.83%
# t = 1.08	Evolución al 10.84%
# t = 1.08	Evolución al 10.85%
# t = 1.09	Evolución al 10.86%
# t = 1.09	Evolución al 10.87%
# t = 1.09	Evolución al 10.88%
# t = 1.09	Evolución al 10.89%
# t = 1.09	Evolución al 10.9%
# t = 1.09	Evolución al 10.91%
# t = 1.09	Evolución al 10.92%
# t = 1.09	Evolución al 10.93%
# t = 1.09	Evolución al 10.94%
# t = 1.09	Evolución al 10.95%
# t = 1.1	Evolución al 10.96%
# t = 1.1	Evolución al 10.97%
# t = 1.1	Evolución al 10.98%
# t = 1.1	Evolución al 10.99%
# t = 1.1	Evolución al 11.0%
# t = 1.1	Evolución al 11.01%
# t = 1.1	Evolución al 11.02%
# t = 1.1	Evolución al 11.03%
# t = 1.1	Evolución al 11.04%
# t = 1.1	Evolución al 11.05%
# t = 1.11	Evolución al 11.06%
# t = 1.11	Evolución al 11.07%
# t = 1.11	Evolución al 11.08%
# t = 1.11	Evolución al 11.09%
# t = 1.11	Evolución al 11.1%
# t = 1.11	Evolución al 11.11%
# t = 1.11	Evolución al 11.12%
# t = 1.11	Evolución al 11.13%
# t = 1.11	Evolución al 11.14%
# t = 1.11	Evolución al 11.15%
# t = 1.12	Evolución al 11.16%
# t = 1.12	Evolución al 11.17%
# t = 1.12	Evolución al 11.18%
# t = 1.12	Evolución al 11.19%
# t = 1.12	Evolución al 11.2%
# t = 1.12	Evolución al 11.21%
# t = 1.12	Evolución al 11.22%
# t = 1.12	Evolución al 11.23%
# t = 1.12	Evolución al 11.24%
# t = 1.12	Evolución al 11.25%
# t = 1.13	Evolución al 11.26%
# t = 1.13	Evolución al 11.27%
# t = 1.13	Evolución al 11.28%
# t = 1.13	Evolución al 11.29%
# t = 1.13	Evolución al 11.3%
# t = 1.13	Evolución al 11.31%
# t = 1.13	Evolución al 11.32%
# t = 1.13	Evolución al 11.33%
# t = 1.13	Evolución al 11.34%
# t = 1.13	Evolución al 11.35%
# t = 1.14	Evolución al 11.36%
# t = 1.14	Evolución al 11.37%
# t = 1.14	Evolución al 11.38%
# t = 1.14	Evolución al 11.39%
# t = 1.14	Evolución al 11.4%
# t = 1.14	Evolución al 11.41%
# t = 1.14	Evolución al 11.42%
# t = 1.14	Evolución al 11.43%
# t = 1.14	Evolución al 11.44%
# t = 1.14	Evolución al 11.45%
# t = 1.15	Evolución al 11.46%
# t = 1.15	Evolución al 11.47%
# t = 1.15	Evolución al 11.48%
# t = 1.15	Evolución al 11.49%
# t = 1.15	Evolución al 11.5%
# t = 1.15	Evolución al 11.51%
# t = 1.15	Evolución al 11.52%
# t = 1.15	Evolución al 11.53%
# t = 1.15	Evolución al 11.54%
# t = 1.15	Evolución al 11.55%
# t = 1.16	Evolución al 11.56%
# t = 1.16	Evolución al 11.57%
# t = 1.16	Evolución al 11.58%
# t = 1.16	Evolución al 11.59%
# t = 1.16	Evolución al 11.6%
# t = 1.16	Evolución al 11.61%
# t = 1.16	Evolución al 11.62%
# t = 1.16	Evolución al 11.63%
# t = 1.16	Evolución al 11.64%
# t = 1.16	Evolución al 11.65%
# t = 1.17	Evolución al 11.66%
# t = 1.17	Evolución al 11.67%
# t = 1.17	Evolución al 11.68%
# t = 1.17	Evolución al 11.69%
# t = 1.17	Evolución al 11.7%
# t = 1.17	Evolución al 11.71%
# t = 1.17	Evolución al 11.72%
# t = 1.17	Evolución al 11.73%
# t = 1.17	Evolución al 11.74%
# t = 1.17	Evolución al 11.75%
# t = 1.18	Evolución al 11.76%
# t = 1.18	Evolución al 11.77%
# t = 1.18	Evolución al 11.78%
# t = 1.18	Evolución al 11.79%
# t = 1.18	Evolución al 11.8%
# t = 1.18	Evolución al 11.81%
# t = 1.18	Evolución al 11.82%
# t = 1.18	Evolución al 11.83%
# t = 1.18	Evolución al 11.84%
# t = 1.18	Evolución al 11.85%
# t = 1.19	Evolución al 11.86%
# t = 1.19	Evolución al 11.87%
# t = 1.19	Evolución al 11.88%
# t = 1.19	Evolución al 11.89%
# t = 1.19	Evolución al 11.9%
# t = 1.19	Evolución al 11.91%
# t = 1.19	Evolución al 11.92%
# t = 1.19	Evolución al 11.93%
# t = 1.19	Evolución al 11.94%
# t = 1.19	Evolución al 11.95%
# t = 1.2	Evolución al 11.96%
# t = 1.2	Evolución al 11.97%
# t = 1.2	Evolución al 11.98%
# t = 1.2	Evolución al 11.99%
# t = 1.2	Evolución al 12.0%
# t = 1.2	Evolución al 12.01%
# t = 1.2	Evolución al 12.02%
# t = 1.2	Evolución al 12.03%
# t = 1.2	Evolución al 12.04%
# t = 1.2	Evolución al 12.05%
# t = 1.21	Evolución al 12.06%
# t = 1.21	Evolución al 12.07%
# t = 1.21	Evolución al 12.08%
# t = 1.21	Evolución al 12.09%
# t = 1.21	Evolución al 12.1%
# t = 1.21	Evolución al 12.11%
# t = 1.21	Evolución al 12.12%
# t = 1.21	Evolución al 12.13%
# t = 1.21	Evolución al 12.14%
# t = 1.21	Evolución al 12.15%
# t = 1.22	Evolución al 12.16%
# t = 1.22	Evolución al 12.17%
# t = 1.22	Evolución al 12.18%
# t = 1.22	Evolución al 12.19%
# t = 1.22	Evolución al 12.2%
# t = 1.22	Evolución al 12.21%
# t = 1.22	Evolución al 12.22%
# t = 1.22	Evolución al 12.23%
# t = 1.22	Evolución al 12.24%
# t = 1.22	Evolución al 12.25%
# t = 1.23	Evolución al 12.26%
# t = 1.23	Evolución al 12.27%
# t = 1.23	Evolución al 12.28%
# t = 1.23	Evolución al 12.29%
# t = 1.23	Evolución al 12.3%
# t = 1.23	Evolución al 12.31%
# t = 1.23	Evolución al 12.32%
# t = 1.23	Evolución al 12.33%
# t = 1.23	Evolución al 12.34%
# t = 1.23	Evolución al 12.35%
# t = 1.24	Evolución al 12.36%
# t = 1.24	Evolución al 12.37%
# t = 1.24	Evolución al 12.38%
# t = 1.24	Evolución al 12.39%
# t = 1.24	Evolución al 12.4%
# t = 1.24	Evolución al 12.41%
# t = 1.24	Evolución al 12.42%
# t = 1.24	Evolución al 12.43%
# t = 1.24	Evolución al 12.44%
# t = 1.24	Evolución al 12.45%
# t = 1.25	Evolución al 12.46%
# t = 1.25	Evolución al 12.47%
# t = 1.25	Evolución al 12.48%
# t = 1.25	Evolución al 12.49%
# t = 1.25	Evolución al 12.5%
# t = 1.25	Evolución al 12.51%
# t = 1.25	Evolución al 12.52%
# t = 1.25	Evolución al 12.53%
# t = 1.25	Evolución al 12.54%
# t = 1.25	Evolución al 12.55%
# t = 1.26	Evolución al 12.56%
# t = 1.26	Evolución al 12.57%
# t = 1.26	Evolución al 12.58%
# t = 1.26	Evolución al 12.59%
# t = 1.26	Evolución al 12.6%
# t = 1.26	Evolución al 12.61%
# t = 1.26	Evolución al 12.62%
# t = 1.26	Evolución al 12.63%
# t = 1.26	Evolución al 12.64%
# t = 1.26	Evolución al 12.65%
# t = 1.27	Evolución al 12.66%
# t = 1.27	Evolución al 12.67%
# t = 1.27	Evolución al 12.68%
# t = 1.27	Evolución al 12.69%
# t = 1.27	Evolución al 12.7%
# t = 1.27	Evolución al 12.71%
# t = 1.27	Evolución al 12.72%
# t = 1.27	Evolución al 12.73%
# t = 1.27	Evolución al 12.74%
# t = 1.27	Evolución al 12.75%
# t = 1.28	Evolución al 12.76%
# t = 1.28	Evolución al 12.77%
# t = 1.28	Evolución al 12.78%
# t = 1.28	Evolución al 12.79%
# t = 1.28	Evolución al 12.8%
# t = 1.28	Evolución al 12.81%
# t = 1.28	Evolución al 12.82%
# t = 1.28	Evolución al 12.83%
# t = 1.28	Evolución al 12.84%
# t = 1.28	Evolución al 12.85%
# t = 1.29	Evolución al 12.86%
# t = 1.29	Evolución al 12.87%
# t = 1.29	Evolución al 12.88%
# t = 1.29	Evolución al 12.89%
# t = 1.29	Evolución al 12.9%
# t = 1.29	Evolución al 12.91%
# t = 1.29	Evolución al 12.92%
# t = 1.29	Evolución al 12.93%
# t = 1.29	Evolución al 12.94%
# t = 1.3	Evolución al 12.95%
# t = 1.3	Evolución al 12.96%
# t = 1.3	Evolución al 12.97%
# t = 1.3	Evolución al 12.98%
# t = 1.3	Evolución al 12.99%
# t = 1.3	Evolución al 13.0%
# t = 1.3	Evolución al 13.01%
# t = 1.3	Evolución al 13.02%
# t = 1.3	Evolución al 13.03%
# t = 1.3	Evolución al 13.04%
# t = 1.31	Evolución al 13.05%
# t = 1.31	Evolución al 13.06%
# t = 1.31	Evolución al 13.07%
# t = 1.31	Evolución al 13.08%
# t = 1.31	Evolución al 13.09%
# t = 1.31	Evolución al 13.1%
# t = 1.31	Evolución al 13.11%
# t = 1.31	Evolución al 13.12%
# t = 1.31	Evolución al 13.13%
# t = 1.31	Evolución al 13.14%
# t = 1.32	Evolución al 13.15%
# t = 1.32	Evolución al 13.16%
# t = 1.32	Evolución al 13.17%
# t = 1.32	Evolución al 13.18%
# t = 1.32	Evolución al 13.19%
# t = 1.32	Evolución al 13.2%
# t = 1.32	Evolución al 13.21%
# t = 1.32	Evolución al 13.22%
# t = 1.32	Evolución al 13.23%
# t = 1.32	Evolución al 13.24%
# t = 1.33	Evolución al 13.25%
# t = 1.33	Evolución al 13.26%
# t = 1.33	Evolución al 13.27%
# t = 1.33	Evolución al 13.28%
# t = 1.33	Evolución al 13.29%
# t = 1.33	Evolución al 13.3%
# t = 1.33	Evolución al 13.31%
# t = 1.33	Evolución al 13.32%
# t = 1.33	Evolución al 13.33%
# t = 1.33	Evolución al 13.34%
# t = 1.34	Evolución al 13.35%
# t = 1.34	Evolución al 13.36%
# t = 1.34	Evolución al 13.37%
# t = 1.34	Evolución al 13.38%
# t = 1.34	Evolución al 13.39%
# t = 1.34	Evolución al 13.4%
# t = 1.34	Evolución al 13.41%
# t = 1.34	Evolución al 13.42%
# t = 1.34	Evolución al 13.43%
# t = 1.34	Evolución al 13.44%
# t = 1.35	Evolución al 13.45%
# t = 1.35	Evolución al 13.46%
# t = 1.35	Evolución al 13.47%
# t = 1.35	Evolución al 13.48%
# t = 1.35	Evolución al 13.49%
# t = 1.35	Evolución al 13.5%
# t = 1.35	Evolución al 13.51%
# t = 1.35	Evolución al 13.52%
# t = 1.35	Evolución al 13.53%
# t = 1.35	Evolución al 13.54%
# t = 1.36	Evolución al 13.55%
# t = 1.36	Evolución al 13.56%
# t = 1.36	Evolución al 13.57%
# t = 1.36	Evolución al 13.58%
# t = 1.36	Evolución al 13.59%
# t = 1.36	Evolución al 13.6%
# t = 1.36	Evolución al 13.61%
# t = 1.36	Evolución al 13.62%
# t = 1.36	Evolución al 13.63%
# t = 1.36	Evolución al 13.64%
# t = 1.37	Evolución al 13.65%
# t = 1.37	Evolución al 13.66%
# t = 1.37	Evolución al 13.67%
# t = 1.37	Evolución al 13.68%
# t = 1.37	Evolución al 13.69%
# t = 1.37	Evolución al 13.7%
# t = 1.37	Evolución al 13.71%
# t = 1.37	Evolución al 13.72%
# t = 1.37	Evolución al 13.73%
# t = 1.37	Evolución al 13.74%
# t = 1.38	Evolución al 13.75%
# t = 1.38	Evolución al 13.76%
# t = 1.38	Evolución al 13.77%
# t = 1.38	Evolución al 13.78%
# t = 1.38	Evolución al 13.79%
# t = 1.38	Evolución al 13.8%
# t = 1.38	Evolución al 13.81%
# t = 1.38	Evolución al 13.82%
# t = 1.38	Evolución al 13.83%
# t = 1.38	Evolución al 13.84%
# t = 1.39	Evolución al 13.85%
# t = 1.39	Evolución al 13.86%
# t = 1.39	Evolución al 13.87%
# t = 1.39	Evolución al 13.88%
# t = 1.39	Evolución al 13.89%
# t = 1.39	Evolución al 13.9%
# t = 1.39	Evolución al 13.91%
# t = 1.39	Evolución al 13.92%
# t = 1.39	Evolución al 13.93%
# t = 1.39	Evolución al 13.94%
# t = 1.4	Evolución al 13.95%
# t = 1.4	Evolución al 13.96%
# t = 1.4	Evolución al 13.97%
# t = 1.4	Evolución al 13.98%
# t = 1.4	Evolución al 13.99%
# t = 1.4	Evolución al 14.0%
# t = 1.4	Evolución al 14.01%
# t = 1.4	Evolución al 14.02%
# t = 1.4	Evolución al 14.03%
# t = 1.4	Evolución al 14.04%
# t = 1.41	Evolución al 14.05%
# t = 1.41	Evolución al 14.06%
# t = 1.41	Evolución al 14.07%
# t = 1.41	Evolución al 14.08%
# t = 1.41	Evolución al 14.09%
# t = 1.41	Evolución al 14.1%
# t = 1.41	Evolución al 14.11%
# t = 1.41	Evolución al 14.12%
# t = 1.41	Evolución al 14.13%
# t = 1.41	Evolución al 14.14%
# t = 1.42	Evolución al 14.15%
# t = 1.42	Evolución al 14.16%
# t = 1.42	Evolución al 14.17%
# t = 1.42	Evolución al 14.18%
# t = 1.42	Evolución al 14.19%
# t = 1.42	Evolución al 14.2%
# t = 1.42	Evolución al 14.21%
# t = 1.42	Evolución al 14.22%
# t = 1.42	Evolución al 14.23%
# t = 1.42	Evolución al 14.24%
# t = 1.43	Evolución al 14.25%
# t = 1.43	Evolución al 14.26%
# t = 1.43	Evolución al 14.27%
# t = 1.43	Evolución al 14.28%
# t = 1.43	Evolución al 14.29%
# t = 1.43	Evolución al 14.3%
# t = 1.43	Evolución al 14.31%
# t = 1.43	Evolución al 14.32%
# t = 1.43	Evolución al 14.33%
# t = 1.43	Evolución al 14.34%
# t = 1.44	Evolución al 14.35%
# t = 1.44	Evolución al 14.36%
# t = 1.44	Evolución al 14.37%
# t = 1.44	Evolución al 14.38%
# t = 1.44	Evolución al 14.39%
# t = 1.44	Evolución al 14.4%
# t = 1.44	Evolución al 14.41%
# t = 1.44	Evolución al 14.42%
# t = 1.44	Evolución al 14.43%
# t = 1.44	Evolución al 14.44%
# t = 1.45	Evolución al 14.45%
# t = 1.45	Evolución al 14.46%
# t = 1.45	Evolución al 14.47%
# t = 1.45	Evolución al 14.48%
# t = 1.45	Evolución al 14.49%
# t = 1.45	Evolución al 14.5%
# t = 1.45	Evolución al 14.51%
# t = 1.45	Evolución al 14.52%
# t = 1.45	Evolución al 14.53%
# t = 1.45	Evolución al 14.54%
# t = 1.46	Evolución al 14.55%
# t = 1.46	Evolución al 14.56%
# t = 1.46	Evolución al 14.57%
# t = 1.46	Evolución al 14.58%
# t = 1.46	Evolución al 14.59%
# t = 1.46	Evolución al 14.6%
# t = 1.46	Evolución al 14.61%
# t = 1.46	Evolución al 14.62%
# t = 1.46	Evolución al 14.63%
# t = 1.46	Evolución al 14.64%
# t = 1.47	Evolución al 14.65%
# t = 1.47	Evolución al 14.66%
# t = 1.47	Evolución al 14.67%
# t = 1.47	Evolución al 14.68%
# t = 1.47	Evolución al 14.69%
# t = 1.47	Evolución al 14.7%
# t = 1.47	Evolución al 14.71%
# t = 1.47	Evolución al 14.72%
# t = 1.47	Evolución al 14.73%
# t = 1.47	Evolución al 14.74%
# t = 1.48	Evolución al 14.75%
# t = 1.48	Evolución al 14.76%
# t = 1.48	Evolución al 14.77%
# t = 1.48	Evolución al 14.78%
# t = 1.48	Evolución al 14.79%
# t = 1.48	Evolución al 14.8%
# t = 1.48	Evolución al 14.81%
# t = 1.48	Evolución al 14.82%
# t = 1.48	Evolución al 14.83%
# t = 1.48	Evolución al 14.84%
# t = 1.49	Evolución al 14.85%
# t = 1.49	Evolución al 14.86%
# t = 1.49	Evolución al 14.87%
# t = 1.49	Evolución al 14.88%
# t = 1.49	Evolución al 14.89%
# t = 1.49	Evolución al 14.9%
# t = 1.49	Evolución al 14.91%
# t = 1.49	Evolución al 14.92%
# t = 1.49	Evolución al 14.93%
# t = 1.49	Evolución al 14.94%
# t = 1.5	Evolución al 14.95%
# t = 1.5	Evolución al 14.96%
# t = 1.5	Evolución al 14.97%
# t = 1.5	Evolución al 14.98%
# t = 1.5	Evolución al 14.99%
# t = 1.5	Evolución al 15.0%
# t = 1.5	Evolución al 15.01%
# t = 1.5	Evolución al 15.02%
# t = 1.5	Evolución al 15.03%
# t = 1.5	Evolución al 15.04%
# t = 1.51	Evolución al 15.05%
# t = 1.51	Evolución al 15.06%
# t = 1.51	Evolución al 15.07%
# t = 1.51	Evolución al 15.08%
# t = 1.51	Evolución al 15.09%
# t = 1.51	Evolución al 15.1%
# t = 1.51	Evolución al 15.11%
# t = 1.51	Evolución al 15.12%
# t = 1.51	Evolución al 15.13%
# t = 1.51	Evolución al 15.14%
# t = 1.52	Evolución al 15.15%
# t = 1.52	Evolución al 15.16%
# t = 1.52	Evolución al 15.17%
# t = 1.52	Evolución al 15.18%
# t = 1.52	Evolución al 15.19%
# t = 1.52	Evolución al 15.2%
# t = 1.52	Evolución al 15.21%
# t = 1.52	Evolución al 15.22%
# t = 1.52	Evolución al 15.23%
# t = 1.52	Evolución al 15.24%
# t = 1.53	Evolución al 15.25%
# t = 1.53	Evolución al 15.26%
# t = 1.53	Evolución al 15.27%
# t = 1.53	Evolución al 15.28%
# t = 1.53	Evolución al 15.29%
# t = 1.53	Evolución al 15.3%
# t = 1.53	Evolución al 15.31%
# t = 1.53	Evolución al 15.32%
# t = 1.53	Evolución al 15.33%
# t = 1.53	Evolución al 15.34%
# t = 1.54	Evolución al 15.35%
# t = 1.54	Evolución al 15.36%
# t = 1.54	Evolución al 15.37%
# t = 1.54	Evolución al 15.38%
# t = 1.54	Evolución al 15.39%
# t = 1.54	Evolución al 15.4%
# t = 1.54	Evolución al 15.41%
# t = 1.54	Evolución al 15.42%
# t = 1.54	Evolución al 15.43%
# t = 1.54	Evolución al 15.44%
# t = 1.55	Evolución al 15.45%
# t = 1.55	Evolución al 15.46%
# t = 1.55	Evolución al 15.47%
# t = 1.55	Evolución al 15.48%
# t = 1.55	Evolución al 15.49%
# t = 1.55	Evolución al 15.5%
# t = 1.55	Evolución al 15.51%
# t = 1.55	Evolución al 15.52%
# t = 1.55	Evolución al 15.53%
# t = 1.55	Evolución al 15.54%
# t = 1.56	Evolución al 15.55%
# t = 1.56	Evolución al 15.56%
# t = 1.56	Evolución al 15.57%
# t = 1.56	Evolución al 15.58%
# t = 1.56	Evolución al 15.59%
# t = 1.56	Evolución al 15.6%
# t = 1.56	Evolución al 15.61%
# t = 1.56	Evolución al 15.62%
# t = 1.56	Evolución al 15.63%
# t = 1.56	Evolución al 15.64%
# t = 1.57	Evolución al 15.65%
# t = 1.57	Evolución al 15.66%
# t = 1.57	Evolución al 15.67%
# t = 1.57	Evolución al 15.68%
# t = 1.57	Evolución al 15.69%
# t = 1.57	Evolución al 15.7%
# t = 1.57	Evolución al 15.71%
# t = 1.57	Evolución al 15.72%
# t = 1.57	Evolución al 15.73%
# t = 1.57	Evolución al 15.74%
# t = 1.58	Evolución al 15.75%
# t = 1.58	Evolución al 15.76%
# t = 1.58	Evolución al 15.77%
# t = 1.58	Evolución al 15.78%
# t = 1.58	Evolución al 15.79%
# t = 1.58	Evolución al 15.8%
# t = 1.58	Evolución al 15.81%
# t = 1.58	Evolución al 15.82%
# t = 1.58	Evolución al 15.83%
# t = 1.58	Evolución al 15.84%
# t = 1.59	Evolución al 15.85%
# t = 1.59	Evolución al 15.86%
# t = 1.59	Evolución al 15.87%
# t = 1.59	Evolución al 15.88%
# t = 1.59	Evolución al 15.89%
# t = 1.59	Evolución al 15.9%
# t = 1.59	Evolución al 15.91%
# t = 1.59	Evolución al 15.92%
# t = 1.59	Evolución al 15.93%
# t = 1.59	Evolución al 15.94%
# t = 1.6	Evolución al 15.95%
# t = 1.6	Evolución al 15.96%
# t = 1.6	Evolución al 15.97%
# t = 1.6	Evolución al 15.98%
# t = 1.6	Evolución al 15.99%
# t = 1.6	Evolución al 16.0%
# t = 1.6	Evolución al 16.01%
# t = 1.6	Evolución al 16.02%
# t = 1.6	Evolución al 16.03%
# t = 1.6	Evolución al 16.04%
# t = 1.61	Evolución al 16.05%
# t = 1.61	Evolución al 16.06%
# t = 1.61	Evolución al 16.07%
# t = 1.61	Evolución al 16.08%
# t = 1.61	Evolución al 16.09%
# t = 1.61	Evolución al 16.1%
# t = 1.61	Evolución al 16.11%
# t = 1.61	Evolución al 16.12%
# t = 1.61	Evolución al 16.13%
# t = 1.61	Evolución al 16.14%
# t = 1.62	Evolución al 16.15%
# t = 1.62	Evolución al 16.16%
# t = 1.62	Evolución al 16.17%
# t = 1.62	Evolución al 16.18%
# t = 1.62	Evolución al 16.19%
# t = 1.62	Evolución al 16.2%
# t = 1.62	Evolución al 16.21%
# t = 1.62	Evolución al 16.22%
# t = 1.62	Evolución al 16.23%
# t = 1.62	Evolución al 16.24%
# t = 1.63	Evolución al 16.25%
# t = 1.63	Evolución al 16.26%
# t = 1.63	Evolución al 16.27%
# t = 1.63	Evolución al 16.28%
# t = 1.63	Evolución al 16.29%
# t = 1.63	Evolución al 16.3%
# t = 1.63	Evolución al 16.31%
# t = 1.63	Evolución al 16.32%
# t = 1.63	Evolución al 16.33%
# t = 1.63	Evolución al 16.34%
# t = 1.64	Evolución al 16.35%
# t = 1.64	Evolución al 16.36%
# t = 1.64	Evolución al 16.37%
# t = 1.64	Evolución al 16.38%
# t = 1.64	Evolución al 16.39%
# t = 1.64	Evolución al 16.4%
# t = 1.64	Evolución al 16.41%
# t = 1.64	Evolución al 16.42%
# t = 1.64	Evolución al 16.43%
# t = 1.64	Evolución al 16.44%
# t = 1.65	Evolución al 16.45%
# t = 1.65	Evolución al 16.46%
# t = 1.65	Evolución al 16.47%
# t = 1.65	Evolución al 16.48%
# t = 1.65	Evolución al 16.49%
# t = 1.65	Evolución al 16.5%
# t = 1.65	Evolución al 16.51%
# t = 1.65	Evolución al 16.52%
# t = 1.65	Evolución al 16.53%
# t = 1.65	Evolución al 16.54%
# t = 1.66	Evolución al 16.55%
# t = 1.66	Evolución al 16.56%
# t = 1.66	Evolución al 16.57%
# t = 1.66	Evolución al 16.58%
# t = 1.66	Evolución al 16.59%
# t = 1.66	Evolución al 16.6%
# t = 1.66	Evolución al 16.61%
# t = 1.66	Evolución al 16.62%
# t = 1.66	Evolución al 16.63%
# t = 1.66	Evolución al 16.64%
# t = 1.67	Evolución al 16.65%
# t = 1.67	Evolución al 16.66%
# t = 1.67	Evolución al 16.67%
# t = 1.67	Evolución al 16.68%
# t = 1.67	Evolución al 16.69%
# t = 1.67	Evolución al 16.7%
# t = 1.67	Evolución al 16.71%
# t = 1.67	Evolución al 16.72%
# t = 1.67	Evolución al 16.73%
# t = 1.67	Evolución al 16.74%
# t = 1.68	Evolución al 16.75%
# t = 1.68	Evolución al 16.76%
# t = 1.68	Evolución al 16.77%
# t = 1.68	Evolución al 16.78%
# t = 1.68	Evolución al 16.79%
# t = 1.68	Evolución al 16.8%
# t = 1.68	Evolución al 16.81%
# t = 1.68	Evolución al 16.82%
# t = 1.68	Evolución al 16.83%
# t = 1.68	Evolución al 16.84%
# t = 1.69	Evolución al 16.85%
# t = 1.69	Evolución al 16.86%
# t = 1.69	Evolución al 16.87%
# t = 1.69	Evolución al 16.88%
# t = 1.69	Evolución al 16.89%
# t = 1.69	Evolución al 16.9%
# t = 1.69	Evolución al 16.91%
# t = 1.69	Evolución al 16.92%
# t = 1.69	Evolución al 16.93%
# t = 1.69	Evolución al 16.94%
# t = 1.7	Evolución al 16.95%
# t = 1.7	Evolución al 16.96%
# t = 1.7	Evolución al 16.97%
# t = 1.7	Evolución al 16.98%
# t = 1.7	Evolución al 16.99%
# t = 1.7	Evolución al 17.0%
# ...
# t = 9.44	Evolución al 94.45%
# t = 9.45	Evolución al 94.46%
# t = 9.45	Evolución al 94.47%
# t = 9.45	Evolución al 94.48%
# t = 9.45	Evolución al 94.49%
# t = 9.45	Evolución al 94.5%
# t = 9.45	Evolución al 94.51%
# t = 9.45	Evolución al 94.52%
# t = 9.45	Evolución al 94.53%
# t = 9.45	Evolución al 94.54%
# t = 9.45	Evolución al 94.55%
# t = 9.46	Evolución al 94.56%
# t = 9.46	Evolución al 94.57%
# t = 9.46	Evolución al 94.58%
# t = 9.46	Evolución al 94.59%
# t = 9.46	Evolución al 94.6%
# t = 9.46	Evolución al 94.61%
# t = 9.46	Evolución al 94.62%
# t = 9.46	Evolución al 94.63%
# t = 9.46	Evolución al 94.64%
# t = 9.46	Evolución al 94.65%
# t = 9.47	Evolución al 94.66%
# t = 9.47	Evolución al 94.67%
# t = 9.47	Evolución al 94.68%
# t = 9.47	Evolución al 94.69%
# t = 9.47	Evolución al 94.7%
# t = 9.47	Evolución al 94.71%
# t = 9.47	Evolución al 94.72%
# t = 9.47	Evolución al 94.73%
# t = 9.47	Evolución al 94.74%
# t = 9.47	Evolución al 94.75%
# t = 9.48	Evolución al 94.76%
# t = 9.48	Evolución al 94.77%
# t = 9.48	Evolución al 94.78%
# t = 9.48	Evolución al 94.79%
# t = 9.48	Evolución al 94.8%
# t = 9.48	Evolución al 94.81%
# t = 9.48	Evolución al 94.82%
# t = 9.48	Evolución al 94.83%
# t = 9.48	Evolución al 94.84%
# t = 9.48	Evolución al 94.85%
# t = 9.49	Evolución al 94.86%
# t = 9.49	Evolución al 94.87%
# t = 9.49	Evolución al 94.88%
# t = 9.49	Evolución al 94.89%
# t = 9.49	Evolución al 94.9%
# t = 9.49	Evolución al 94.91%
# t = 9.49	Evolución al 94.92%
# t = 9.49	Evolución al 94.93%
# t = 9.49	Evolución al 94.94%
# t = 9.49	Evolución al 94.95%
# t = 9.5	Evolución al 94.96%
# t = 9.5	Evolución al 94.97%
# t = 9.5	Evolución al 94.98%
# t = 9.5	Evolución al 94.99%
# t = 9.5	Evolución al 95.0%
# t = 9.5	Evolución al 95.01%
# t = 9.5	Evolución al 95.02%
# t = 9.5	Evolución al 95.03%
# t = 9.5	Evolución al 95.04%
# t = 9.5	Evolución al 95.05%
# t = 9.51	Evolución al 95.06%
# t = 9.51	Evolución al 95.07%
# t = 9.51	Evolución al 95.08%
# t = 9.51	Evolución al 95.09%
# t = 9.51	Evolución al 95.1%
# t = 9.51	Evolución al 95.11%
# t = 9.51	Evolución al 95.12%
# t = 9.51	Evolución al 95.13%
# t = 9.51	Evolución al 95.14%
# t = 9.51	Evolución al 95.15%
# t = 9.52	Evolución al 95.16%
# t = 9.52	Evolución al 95.17%
# t = 9.52	Evolución al 95.18%
# t = 9.52	Evolución al 95.19%
# t = 9.52	Evolución al 95.2%
# t = 9.52	Evolución al 95.21%
# t = 9.52	Evolución al 95.22%
# t = 9.52	Evolución al 95.23%
# t = 9.52	Evolución al 95.24%
# t = 9.52	Evolución al 95.25%
# t = 9.53	Evolución al 95.26%
# t = 9.53	Evolución al 95.27%
# t = 9.53	Evolución al 95.28%
# t = 9.53	Evolución al 95.29%
# t = 9.53	Evolución al 95.3%
# t = 9.53	Evolución al 95.31%
# t = 9.53	Evolución al 95.32%
# t = 9.53	Evolución al 95.33%
# t = 9.53	Evolución al 95.34%
# t = 9.53	Evolución al 95.35%
# t = 9.54	Evolución al 95.36%
# t = 9.54	Evolución al 95.37%
# t = 9.54	Evolución al 95.38%
# t = 9.54	Evolución al 95.39%
# t = 9.54	Evolución al 95.4%
# t = 9.54	Evolución al 95.41%
# t = 9.54	Evolución al 95.42%
# t = 9.54	Evolución al 95.43%
# t = 9.54	Evolución al 95.44%
# t = 9.54	Evolución al 95.45%
# t = 9.55	Evolución al 95.46%
# t = 9.55	Evolución al 95.47%
# t = 9.55	Evolución al 95.48%
# t = 9.55	Evolución al 95.49%
# t = 9.55	Evolución al 95.5%
# t = 9.55	Evolución al 95.51%
# t = 9.55	Evolución al 95.52%
# t = 9.55	Evolución al 95.53%
# t = 9.55	Evolución al 95.54%
# t = 9.55	Evolución al 95.55%
# t = 9.56	Evolución al 95.56%
# t = 9.56	Evolución al 95.57%
# t = 9.56	Evolución al 95.58%
# t = 9.56	Evolución al 95.59%
# t = 9.56	Evolución al 95.6%
# t = 9.56	Evolución al 95.61%
# t = 9.56	Evolución al 95.62%
# t = 9.56	Evolución al 95.63%
# t = 9.56	Evolución al 95.64%
# t = 9.56	Evolución al 95.65%
# t = 9.57	Evolución al 95.66%
# t = 9.57	Evolución al 95.67%
# t = 9.57	Evolución al 95.68%
# t = 9.57	Evolución al 95.69%
# t = 9.57	Evolución al 95.7%
# t = 9.57	Evolución al 95.71%
# t = 9.57	Evolución al 95.72%
# t = 9.57	Evolución al 95.73%
# t = 9.57	Evolución al 95.74%
# t = 9.57	Evolución al 95.75%
# t = 9.58	Evolución al 95.76%
# t = 9.58	Evolución al 95.77%
# t = 9.58	Evolución al 95.78%
# t = 9.58	Evolución al 95.79%
# t = 9.58	Evolución al 95.8%
# t = 9.58	Evolución al 95.81%
# t = 9.58	Evolución al 95.82%
# t = 9.58	Evolución al 95.83%
# t = 9.58	Evolución al 95.84%
# t = 9.58	Evolución al 95.85%
# t = 9.59	Evolución al 95.86%
# t = 9.59	Evolución al 95.87%
# t = 9.59	Evolución al 95.88%
# t = 9.59	Evolución al 95.89%
# t = 9.59	Evolución al 95.9%
# t = 9.59	Evolución al 95.91%
# t = 9.59	Evolución al 95.92%
# t = 9.59	Evolución al 95.93%
# t = 9.59	Evolución al 95.94%
# t = 9.59	Evolución al 95.95%
# t = 9.6	Evolución al 95.96%
# t = 9.6	Evolución al 95.97%
# t = 9.6	Evolución al 95.98%
# t = 9.6	Evolución al 95.99%
# t = 9.6	Evolución al 96.0%
# t = 9.6	Evolución al 96.01%
# t = 9.6	Evolución al 96.02%
# t = 9.6	Evolución al 96.03%
# t = 9.6	Evolución al 96.04%
# t = 9.6	Evolución al 96.05%
# t = 9.61	Evolución al 96.06%
# t = 9.61	Evolución al 96.07%
# t = 9.61	Evolución al 96.08%
# t = 9.61	Evolución al 96.09%
# t = 9.61	Evolución al 96.1%
# t = 9.61	Evolución al 96.11%
# t = 9.61	Evolución al 96.12%
# t = 9.61	Evolución al 96.13%
# t = 9.61	Evolución al 96.14%
# t = 9.61	Evolución al 96.15%
# t = 9.62	Evolución al 96.16%
# t = 9.62	Evolución al 96.17%
# t = 9.62	Evolución al 96.18%
# t = 9.62	Evolución al 96.19%
# t = 9.62	Evolución al 96.2%
# t = 9.62	Evolución al 96.21%
# t = 9.62	Evolución al 96.22%
# t = 9.62	Evolución al 96.23%
# t = 9.62	Evolución al 96.24%
# t = 9.62	Evolución al 96.25%
# t = 9.63	Evolución al 96.26%
# t = 9.63	Evolución al 96.27%
# t = 9.63	Evolución al 96.28%
# t = 9.63	Evolución al 96.29%
# t = 9.63	Evolución al 96.3%
# t = 9.63	Evolución al 96.31%
# t = 9.63	Evolución al 96.32%
# t = 9.63	Evolución al 96.33%
# t = 9.63	Evolución al 96.34%
# t = 9.63	Evolución al 96.35%
# t = 9.64	Evolución al 96.36%
# t = 9.64	Evolución al 96.37%
# t = 9.64	Evolución al 96.38%
# t = 9.64	Evolución al 96.39%
# t = 9.64	Evolución al 96.4%
# t = 9.64	Evolución al 96.41%
# t = 9.64	Evolución al 96.42%
# t = 9.64	Evolución al 96.43%
# t = 9.64	Evolución al 96.44%
# t = 9.64	Evolución al 96.45%
# t = 9.65	Evolución al 96.46%
# t = 9.65	Evolución al 96.47%
# t = 9.65	Evolución al 96.48%
# t = 9.65	Evolución al 96.49%
# t = 9.65	Evolución al 96.5%
# t = 9.65	Evolución al 96.51%
# t = 9.65	Evolución al 96.52%
# t = 9.65	Evolución al 96.53%
# t = 9.65	Evolución al 96.54%
# t = 9.65	Evolución al 96.55%
# t = 9.66	Evolución al 96.56%
# t = 9.66	Evolución al 96.57%
# t = 9.66	Evolución al 96.58%
# t = 9.66	Evolución al 96.59%
# t = 9.66	Evolución al 96.6%
# t = 9.66	Evolución al 96.61%
# t = 9.66	Evolución al 96.62%
# t = 9.66	Evolución al 96.63%
# t = 9.66	Evolución al 96.64%
# t = 9.66	Evolución al 96.65%
# t = 9.67	Evolución al 96.66%
# t = 9.67	Evolución al 96.67%
# t = 9.67	Evolución al 96.68%
# t = 9.67	Evolución al 96.69%
# t = 9.67	Evolución al 96.7%
# t = 9.67	Evolución al 96.71%
# t = 9.67	Evolución al 96.72%
# t = 9.67	Evolución al 96.73%
# t = 9.67	Evolución al 96.74%
# t = 9.67	Evolución al 96.75%
# t = 9.68	Evolución al 96.76%
# t = 9.68	Evolución al 96.77%
# t = 9.68	Evolución al 96.78%
# t = 9.68	Evolución al 96.79%
# t = 9.68	Evolución al 96.8%
# t = 9.68	Evolución al 96.81%
# t = 9.68	Evolución al 96.82%
# t = 9.68	Evolución al 96.83%
# t = 9.68	Evolución al 96.84%
# t = 9.68	Evolución al 96.85%
# t = 9.69	Evolución al 96.86%
# t = 9.69	Evolución al 96.87%
# t = 9.69	Evolución al 96.88%
# t = 9.69	Evolución al 96.89%
# t = 9.69	Evolución al 96.9%
# t = 9.69	Evolución al 96.91%
# t = 9.69	Evolución al 96.92%
# t = 9.69	Evolución al 96.93%
# t = 9.69	Evolución al 96.94%
# t = 9.69	Evolución al 96.95%
# t = 9.7	Evolución al 96.96%
# t = 9.7	Evolución al 96.97%
# t = 9.7	Evolución al 96.98%
# t = 9.7	Evolución al 96.99%
# t = 9.7	Evolución al 97.0%
# t = 9.7	Evolución al 97.01%
# t = 9.7	Evolución al 97.02%
# t = 9.7	Evolución al 97.03%
# t = 9.7	Evolución al 97.04%
# t = 9.7	Evolución al 97.05%
# t = 9.71	Evolución al 97.06%
# t = 9.71	Evolución al 97.07%
# t = 9.71	Evolución al 97.08%
# t = 9.71	Evolución al 97.09%
# t = 9.71	Evolución al 97.1%
# t = 9.71	Evolución al 97.11%
# t = 9.71	Evolución al 97.12%
# t = 9.71	Evolución al 97.13%
# t = 9.71	Evolución al 97.14%
# t = 9.71	Evolución al 97.15%
# t = 9.72	Evolución al 97.16%
# t = 9.72	Evolución al 97.17%
# t = 9.72	Evolución al 97.18%
# t = 9.72	Evolución al 97.19%
# t = 9.72	Evolución al 97.2%
# t = 9.72	Evolución al 97.21%
# t = 9.72	Evolución al 97.22%
# t = 9.72	Evolución al 97.23%
# t = 9.72	Evolución al 97.24%
# t = 9.72	Evolución al 97.25%
# t = 9.73	Evolución al 97.26%
# t = 9.73	Evolución al 97.27%
# t = 9.73	Evolución al 97.28%
# t = 9.73	Evolución al 97.29%
# t = 9.73	Evolución al 97.3%
# t = 9.73	Evolución al 97.31%
# t = 9.73	Evolución al 97.32%
# t = 9.73	Evolución al 97.33%
# t = 9.73	Evolución al 97.34%
# t = 9.73	Evolución al 97.35%
# t = 9.74	Evolución al 97.36%
# t = 9.74	Evolución al 97.37%
# t = 9.74	Evolución al 97.38%
# t = 9.74	Evolución al 97.39%
# t = 9.74	Evolución al 97.4%
# t = 9.74	Evolución al 97.41%
# t = 9.74	Evolución al 97.42%
# t = 9.74	Evolución al 97.43%
# t = 9.74	Evolución al 97.44%
# t = 9.74	Evolución al 97.45%
# t = 9.75	Evolución al 97.46%
# t = 9.75	Evolución al 97.47%
# t = 9.75	Evolución al 97.48%
# t = 9.75	Evolución al 97.49%
# t = 9.75	Evolución al 97.5%
# t = 9.75	Evolución al 97.51%
# t = 9.75	Evolución al 97.52%
# t = 9.75	Evolución al 97.53%
# t = 9.75	Evolución al 97.54%
# t = 9.75	Evolución al 97.55%
# t = 9.76	Evolución al 97.56%
# t = 9.76	Evolución al 97.57%
# t = 9.76	Evolución al 97.58%
# t = 9.76	Evolución al 97.59%
# t = 9.76	Evolución al 97.6%
# t = 9.76	Evolución al 97.61%
# t = 9.76	Evolución al 97.62%
# t = 9.76	Evolución al 97.63%
# t = 9.76	Evolución al 97.64%
# t = 9.76	Evolución al 97.65%
# t = 9.77	Evolución al 97.66%
# t = 9.77	Evolución al 97.67%
# t = 9.77	Evolución al 97.68%
# t = 9.77	Evolución al 97.69%
# t = 9.77	Evolución al 97.7%
# t = 9.77	Evolución al 97.71%
# t = 9.77	Evolución al 97.72%
# t = 9.77	Evolución al 97.73%
# t = 9.77	Evolución al 97.74%
# t = 9.77	Evolución al 97.75%
# t = 9.78	Evolución al 97.76%
# t = 9.78	Evolución al 97.77%
# t = 9.78	Evolución al 97.78%
# t = 9.78	Evolución al 97.79%
# t = 9.78	Evolución al 97.8%
# t = 9.78	Evolución al 97.81%
# t = 9.78	Evolución al 97.82%
# t = 9.78	Evolución al 97.83%
# t = 9.78	Evolución al 97.84%
# t = 9.78	Evolución al 97.85%
# t = 9.79	Evolución al 97.86%
# t = 9.79	Evolución al 97.87%
# t = 9.79	Evolución al 97.88%
# t = 9.79	Evolución al 97.89%
# t = 9.79	Evolución al 97.9%
# t = 9.79	Evolución al 97.91%
# t = 9.79	Evolución al 97.92%
# t = 9.79	Evolución al 97.93%
# t = 9.79	Evolución al 97.94%
# t = 9.79	Evolución al 97.95%
# t = 9.8	Evolución al 97.96%
# t = 9.8	Evolución al 97.97%
# t = 9.8	Evolución al 97.98%
# t = 9.8	Evolución al 97.99%
# t = 9.8	Evolución al 98.0%
# t = 9.8	Evolución al 98.01%
# t = 9.8	Evolución al 98.02%
# t = 9.8	Evolución al 98.03%
# t = 9.8	Evolución al 98.04%
# t = 9.8	Evolución al 98.05%
# t = 9.81	Evolución al 98.06%
# t = 9.81	Evolución al 98.07%
# t = 9.81	Evolución al 98.08%
# t = 9.81	Evolución al 98.09%
# t = 9.81	Evolución al 98.1%
# t = 9.81	Evolución al 98.11%
# t = 9.81	Evolución al 98.12%
# t = 9.81	Evolución al 98.13%
# t = 9.81	Evolución al 98.14%
# t = 9.81	Evolución al 98.15%
# t = 9.82	Evolución al 98.16%
# t = 9.82	Evolución al 98.17%
# t = 9.82	Evolución al 98.18%
# t = 9.82	Evolución al 98.19%
# t = 9.82	Evolución al 98.2%
# t = 9.82	Evolución al 98.21%
# t = 9.82	Evolución al 98.22%
# t = 9.82	Evolución al 98.23%
# t = 9.82	Evolución al 98.24%
# t = 9.82	Evolución al 98.25%
# t = 9.83	Evolución al 98.26%
# t = 9.83	Evolución al 98.27%
# t = 9.83	Evolución al 98.28%
# t = 9.83	Evolución al 98.29%
# t = 9.83	Evolución al 98.3%
# t = 9.83	Evolución al 98.31%
# t = 9.83	Evolución al 98.32%
# t = 9.83	Evolución al 98.33%
# t = 9.83	Evolución al 98.34%
# t = 9.83	Evolución al 98.35%
# t = 9.84	Evolución al 98.36%
# t = 9.84	Evolución al 98.37%
# t = 9.84	Evolución al 98.38%
# t = 9.84	Evolución al 98.39%
# t = 9.84	Evolución al 98.4%
# t = 9.84	Evolución al 98.41%
# t = 9.84	Evolución al 98.42%
# t = 9.84	Evolución al 98.43%
# t = 9.84	Evolución al 98.44%
# t = 9.84	Evolución al 98.45%
# t = 9.85	Evolución al 98.46%
# t = 9.85	Evolución al 98.47%
# t = 9.85	Evolución al 98.48%
# t = 9.85	Evolución al 98.49%
# t = 9.85	Evolución al 98.5%
# t = 9.85	Evolución al 98.51%
# t = 9.85	Evolución al 98.52%
# t = 9.85	Evolución al 98.53%
# t = 9.85	Evolución al 98.54%
# t = 9.85	Evolución al 98.55%
# t = 9.86	Evolución al 98.56%
# t = 9.86	Evolución al 98.57%
# t = 9.86	Evolución al 98.58%
# t = 9.86	Evolución al 98.59%
# t = 9.86	Evolución al 98.6%
# t = 9.86	Evolución al 98.61%
# t = 9.86	Evolución al 98.62%
# t = 9.86	Evolución al 98.63%
# t = 9.86	Evolución al 98.64%
# t = 9.86	Evolución al 98.65%
# t = 9.87	Evolución al 98.66%
# t = 9.87	Evolución al 98.67%
# t = 9.87	Evolución al 98.68%
# t = 9.87	Evolución al 98.69%
# t = 9.87	Evolución al 98.7%
# t = 9.87	Evolución al 98.71%
# t = 9.87	Evolución al 98.72%
# t = 9.87	Evolución al 98.73%
# t = 9.87	Evolución al 98.74%
# t = 9.87	Evolución al 98.75%
# t = 9.88	Evolución al 98.76%
# t = 9.88	Evolución al 98.77%
# t = 9.88	Evolución al 98.78%
# t = 9.88	Evolución al 98.79%
# t = 9.88	Evolución al 98.8%
# t = 9.88	Evolución al 98.81%
# t = 9.88	Evolución al 98.82%
# t = 9.88	Evolución al 98.83%
# t = 9.88	Evolución al 98.84%
# t = 9.88	Evolución al 98.85%
# t = 9.89	Evolución al 98.86%
# t = 9.89	Evolución al 98.87%
# t = 9.89	Evolución al 98.88%
# t = 9.89	Evolución al 98.89%
# t = 9.89	Evolución al 98.9%
# t = 9.89	Evolución al 98.91%
# t = 9.89	Evolución al 98.92%
# t = 9.89	Evolución al 98.93%
# t = 9.89	Evolución al 98.94%
# t = 9.89	Evolución al 98.95%
# t = 9.9	Evolución al 98.96%
# t = 9.9	Evolución al 98.97%
# t = 9.9	Evolución al 98.98%
# t = 9.9	Evolución al 98.99%
# t = 9.9	Evolución al 99.0%
# t = 9.9	Evolución al 99.01%
# t = 9.9	Evolución al 99.02%
# t = 9.9	Evolución al 99.03%
# t = 9.9	Evolución al 99.04%
# t = 9.9	Evolución al 99.05%
# t = 9.91	Evolución al 99.06%
# t = 9.91	Evolución al 99.07%
# t = 9.91	Evolución al 99.08%
# t = 9.91	Evolución al 99.09%
# t = 9.91	Evolución al 99.1%
# t = 9.91	Evolución al 99.11%
# t = 9.91	Evolución al 99.12%
# t = 9.91	Evolución al 99.13%
# t = 9.91	Evolución al 99.14%
# t = 9.91	Evolución al 99.15%
# t = 9.92	Evolución al 99.16%
# t = 9.92	Evolución al 99.17%
# t = 9.92	Evolución al 99.18%
# t = 9.92	Evolución al 99.19%
# t = 9.92	Evolución al 99.2%
# t = 9.92	Evolución al 99.21%
# t = 9.92	Evolución al 99.22%
# t = 9.92	Evolución al 99.23%
# t = 9.92	Evolución al 99.24%
# t = 9.92	Evolución al 99.25%
# t = 9.93	Evolución al 99.26%
# t = 9.93	Evolución al 99.27%
# t = 9.93	Evolución al 99.28%
# t = 9.93	Evolución al 99.29%
# t = 9.93	Evolución al 99.3%
# t = 9.93	Evolución al 99.31%
# t = 9.93	Evolución al 99.32%
# t = 9.93	Evolución al 99.33%
# t = 9.93	Evolución al 99.34%
# t = 9.93	Evolución al 99.35%
# t = 9.94	Evolución al 99.36%
# t = 9.94	Evolución al 99.37%
# t = 9.94	Evolución al 99.38%
# t = 9.94	Evolución al 99.39%
# t = 9.94	Evolución al 99.4%
# t = 9.94	Evolución al 99.41%
# t = 9.94	Evolución al 99.42%
# t = 9.94	Evolución al 99.43%
# t = 9.94	Evolución al 99.44%
# t = 9.94	Evolución al 99.45%
# t = 9.95	Evolución al 99.46%
# t = 9.95	Evolución al 99.47%
# t = 9.95	Evolución al 99.48%
# t = 9.95	Evolución al 99.49%
# t = 9.95	Evolución al 99.5%
# t = 9.95	Evolución al 99.51%
# t = 9.95	Evolución al 99.52%
# t = 9.95	Evolución al 99.53%
# t = 9.95	Evolución al 99.54%
# t = 9.95	Evolución al 99.55%
# t = 9.96	Evolución al 99.56%
# t = 9.96	Evolución al 99.57%
# t = 9.96	Evolución al 99.58%
# t = 9.96	Evolución al 99.59%
# t = 9.96	Evolución al 99.6%
# t = 9.96	Evolución al 99.61%
# t = 9.96	Evolución al 99.62%
# t = 9.96	Evolución al 99.63%
# t = 9.96	Evolución al 99.64%
# t = 9.96	Evolución al 99.65%
# t = 9.97	Evolución al 99.66%
# t = 9.97	Evolución al 99.67%
# t = 9.97	Evolución al 99.68%
# t = 9.97	Evolución al 99.69%
# t = 9.97	Evolución al 99.7%
# t = 9.97	Evolución al 99.71%
# t = 9.97	Evolución al 99.72%
# t = 9.97	Evolución al 99.73%
# t = 9.97	Evolución al 99.74%
# t = 9.97	Evolución al 99.75%
# t = 9.98	Evolución al 99.76%
# t = 9.98	Evolución al 99.77%
# t = 9.98	Evolución al 99.78%
# t = 9.98	Evolución al 99.79%
# t = 9.98	Evolución al 99.8%
# t = 9.98	Evolución al 99.81%
# t = 9.98	Evolución al 99.82%
# t = 9.98	Evolución al 99.83%
# t = 9.98	Evolución al 99.84%
# t = 9.98	Evolución al 99.85%
# t = 9.99	Evolución al 99.86%
# t = 9.99	Evolución al 99.87%
# t = 9.99	Evolución al 99.88%
# t = 9.99	Evolución al 99.89%
# t = 9.99	Evolución al 99.9%
# t = 9.99	Evolución al 99.91%
# t = 9.99	Evolución al 99.92%
# t = 9.99	Evolución al 99.93%
# t = 9.99	Evolución al 99.94%
# t = 9.99	Evolución al 99.95%
# t = 10.0	Evolución al 99.96%
# t = 10.0	Evolución al 99.97%
# t = 10.0	Evolución al 99.98%
# t = 10.0	Evolución al 99.99%

# %%
# Continúo la evolución por n2_pasos pasos de tiempo


# n2_pasos = 2*n_pasos #Correspondientes al segundo ciclo de evolución

# pos_x = np.concatenate((pos_x, np.empty([n2_pasos//guardo_cada, N_esperado])))
# pos_y = np.concatenate((pos_y, np.empty([n2_pasos//guardo_cada, N_esperado])))
# vel_x = np.concatenate((vel_x, np.empty([n2_pasos//guardo_cada, N_esperado])))
# vel_y = np.concatenate((vel_y, np.empty([n2_pasos//guardo_cada, N_esperado])))
# q_tot = np.concatenate((q_tot, np.zeros([n2_pasos//guardo_cada, N_esperado])))


# for i in range(n_pasos, n_pasos + n2_pasos):
#     try:
#         y = avanzo_dt(y, q_vec, t, dt, metodo)
#     except ValueError:
#         print(f"Último índice: {i}")
#         break

#     if i%guardo_cada == 0:
#         print(f"t = {round(t,2)}\tEvolución al {round(i/(n_pasos+n2_pasos)*100,2)}%\tN = {np.sum(q_vec)}")


#     t += dt
#     if i%guardo_cada == 0:
#         pos_x[i//guardo_cada] = np.concatenate((y[0:len(y)//4], np.zeros( N_esperado - len(y)//4)))
#         pos_y[i//guardo_cada] = np.concatenate((y[len(y)//4:2*len(y)//4], np.zeros( N_esperado - len(y)//4)))
#         vel_x[i//guardo_cada] = np.concatenate((y[2*len(y)//4:3*len(y)//4], np.zeros( N_esperado - len(y)//4)))
#         vel_y[i//guardo_cada] = np.concatenate((y[3*len(y)//4:4*len(y)//4], np.zeros( N_esperado - len(y)//4)))
#         q_tot[i//guardo_cada] = q_vec

# n_pasos = n2_pasos + n_pasos

# print("N_tot = ", np.sum(q_vec))

# %%
#Exporto los tiempos
# savetxt_append("resultados/py_cpu_t.txt", np.array([t, dt, n_pasos, guardo_cada]), False)
savetxt_append("resultados/py_cpu_t.txt", np.arange(0, dt*n_pasos, guardo_cada*dt), False)
#Exporto las condiciones iniciales
savetxt_append("resultados/py_cpu_cond_ini.txt", np.array([R0, v0, R0_dim, v0_dim]), False)
