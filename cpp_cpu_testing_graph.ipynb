# %% [markdown]
# # Gráficos de Unit Testing

# %%
#Importo librerías
import numpy as np
import matplotlib.pyplot as plt

# %%
#Importo datos
file = "resultados/cpp_cpu_test_f_maxwell.txt"
data = np.loadtxt(file)

#Hago un histograma
plt.hist(data, bins = 100, density = True)
plt.title("f_maxwell")
# Out:
# Text(0.5, 1.0, 'f_maxwell')
